# %% [markdown]
# **Step 1 - Installation:**
# This first code snipped is simply downloading all the repositories from Bitbucket and Github and installing all of the python library dependencies for them. Be aware this can take upwards of 5 minutes to execute. You should only need to run this a single time!

# %%
# Check our directory just in case
# %cd /content/

# Clone TTPython and Dependencies
#!rm -r ticktalkpython
# !git clone https://bitbucket.org/ccsg-res/ticktalkpython.git
# !cd ticktalkpython && git checkout timing
# !pip install shapely==1.8
# !cd ticktalkpython && pip install -r requirements.txt

# Clone Darknet and Dependencies
#!rm -r darknet
# !git clone https://github.com/AlexeyAB/darknet/
# !cd darknet/ && apt install libopencv-dev python3-opencv ffmpeg
# !pip install nanocamera shapely
# !pip install numpy
# !pip install scikit-learn scipy
# !pip install matplotlib simple_pid

# Build darknet using CPU settings
# !cd darknet && sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !cd darknet && sed -i 's/CUDNN=1/CUDNN=0/g' Makefile
# !cd darknet && sed -i 's/GPU=1/GPU=0/g' Makefile
# !cd darknet && sed -i 's/OPENMP=0/OPENMP=1/g' Makefile
# !cd darknet && sed -i 's/AVX=0/AVX=1/g' Makefile
# !cd darknet && sed -i 's/LIBSO=0/LIBSO=1/g' Makefile
# !cd darknet && make
# !chmod +x /content/darknet/libdarknet.so

# Download files from google drive for use with darknet
print(' Begining to download files... this may take a while...')

folders = ['/content/yolofiles', '/content/yolofiles/cav0', '/content/yolofiles/cav1']

files = [['/content/yolofiles/cav_test.txt', 'https://drive.google.com/u/0/uc?id=1WlL20udwRIoJq5Pkq1L6Iv6M3qhlc0MD&export=download'],
         ['/content/yolofiles/cav_train.txt', 'https://drive.google.com/u/0/uc?id=1bf0MobhUnzKnGjLdsBXGTs2vHOFIM2-w&export=download'],
         ['/content/yolofiles/cav.data', 'https://drive.google.com/u/0/uc?id=1jcEDFQ5n56Hq5tWJXXZ5N3Pg-p9qjq9t&export=download'],
         ['/content/yolofiles/cav.names', 'https://drive.google.com/u/0/uc?id=1hP7bfu5Ei-5w1cub5-vZJ-96mx0LLVMY&export=download'],
         ['/content/yolofiles/yolov4-tiny-cav.cfg', 'https://drive.google.com/u/0/uc?id=1yMQntYWsVbJ8h7x0r0Hv5y34o2IGRVJ2&export=download'],
         ['/content/yolofiles/yolov4-tiny-cav.weights', 'https://drive.google.com/u/0/uc?id=1g8r59Xcn5-n6jpc2ZjQdv-1jsLAiKN9w&export=download'],
         ['/content/yolofiles/cav0/cam_output.txt', 'https://drive.google.com/u/0/uc?id=1Vt5BEkVysTk5dJE0Lb47EQttT46LVB97&export=download'],
         ['/content/yolofiles/cav0/lidar_output.txt', 'https://drive.google.com/u/0/uc?id=1fTYHu3lmEIVjul30EfUyGWyvifPSSAQY&export=download'],
         ['/content/yolofiles/cav0/live_test_output.avi', 'https://drive.google.com/u/0/uc?id=1mqnQVoy8ZH2jDLZehC_J2ihtMcBfnse-&export=download'],
         ['/content/yolofiles/cav1/cam_output.txt', 'https://drive.google.com/u/0/uc?id=1xHz5YmlhRC0ex8PSE5IKB8ZA6DBaakDk&export=download'],
         ['/content/yolofiles/cav1/lidar_output.txt', 'https://drive.google.com/u/0/uc?id=1uYCHBluYurS4GGLSgPRpDsMWAY6GCaGb&export=download'],
         ['/content/yolofiles/cav1/live_test_output.avi', 'https://drive.google.com/u/0/uc?id=1kJnRCRyXbBuwu8RojMJgQy1PEngGmuXc&export=download']]


import os.path
import gdown

# Check that the folders exist or create them
for folder in folders:
  if not os.path.exists(folder):
    os.makedirs(folder)

# Check that the files exist or download them
for file in files:
  if os.path.isfile(file[0]):
    print("File " +  file[0] + " found.")
  else:
    print("Downloading file " +  file[0] + ".")
    gdown.download(file[1], file[0], quiet=False)

# Fix a few lines in cav.data
# !cd /content/yolofiles && sed -i 's/data\//\/content\/yolofiles\//g' cav.data

# Wait for a second for gdown to finish
import time
time.sleep(1)

# Check if we are done, sometime google drive doesn't download the AVI files and it must be done manually!
all_is_good = True
print("\n\nTTPython setup is checking that all files downloaded correctly....\n")
for file in files:
  if not os.path.isfile(file[0]):
    print("File " +  file[0] + " not found. Please download from ", file[1] ," and upload to the following location using the files menu on the left ", file[0])
    all_is_good = False
if all_is_good:
  print("TTPython setup complete, proceed to next block.")
else:
  print("\n!!!TTPython setup did not prpoerly download (a) file(s), please follow the above steps!!!")
# Out:
# /content
# Cloning into 'ticktalkpython'...
# ^C
# /bin/bash: line 1: cd: ticktalkpython: No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 5, in <module>
#     from pip._internal.cli.main import main
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 10, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/build_env.py", line 15, in <module>
#     from pip._vendor.packaging.requirements import Requirement
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/requirements.py", line 10, in <module>
#     from pip._vendor.pyparsing import (  # noqa
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/__init__.py", line 144, in <module>
#     from .helpers import *
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/helpers.py", line 688, in <module>
#     any_open_tag, any_close_tag = make_html_tags(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/helpers.py", line 672, in make_html_tags
#     return _makeTags(tag_str, False)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/helpers.py", line 611, in _makeTags
#     tagAttrValue = quoted_string.copy().set_parse_action(remove_quotes) | Word(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/core.py", line 2755, in __init__
#     _collapse_string_to_ranges(self.initChars),
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pyparsing/util.py", line 206, in _collapse_string_to_ranges
#     s = "".join(sorted(set(s)))
# KeyboardInterrupt
# ^C
# /bin/bash: line 1: cd: ticktalkpython: No such file or directory
# Cloning into 'darknet'...
# remote: Enumerating objects: 15750, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (119/119), done.
# ^C
# /bin/bash: line 1: cd: darknet/: No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 77, in main
#     command = create_command(cmd_name, isolated=("--isolated" in cmd_args))
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/__init__.py", line 114, in create_command
#     module = importlib.import_module(module_path)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 15, in <module>
#     from pip._internal.cli.req_command import (
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 21, in <module>
#     from pip._internal.index.package_finder import PackageFinder
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/index/package_finder.py", line 30, in <module>
#     from pip._internal.req import InstallRequirement
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/req/__init__.py", line 8, in <module>
#     from .req_install import InstallRequirement
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/req/req_install.py", line 42, in <module>
#     from pip._internal.operations.install.wheel import install_wheel
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1012, in get_code
#   File "<frozen importlib._bootstrap_external>", line 672, in _compile_bytecode
# KeyboardInterrupt
# ^C
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %% [markdown]
# **Step 2 - Compile Example 1 in Ticktalk:** Here we will compile example 1 in Ticktalk. Run this cell block and you should see the graph of SQs shown as output.
#
# *Note: Before running this please make sure the last step of the intallation instructions above did not return an error - sometimes the .avi files do not properly download from google drive.*

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

test_name = "example_1_camera_sq"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg
# Out:
# /content/ticktalkpython
# Compiling example_1_camera_sq
# TTPython.Compiler:INFO:: Compilation successful
# TTPython.Compiler:INFO:: Writing ./output/example_1_camera_sq.pickle
# Compiled output found at ./output/example_1_camera_sq.pickle

# %% [markdown]
# **Step 3 - Run Example 1 in Ticktalk:**
# Now that we have compiled example 1 within Ticktalk, lets run the code and see how it goes. Example 1 will spin up a streamify node that reads from a pre-recorded camera stream. This will then be sent to another SQ that will process the camera frames using a darknet based convolutional neural net called YoloV4. Finally the output of each detection frame (CAV locations in in x,y coordinates) will be written to a file in the output folder.
#
# *Note: If this step results in an error check that the intallation instructions did not return an error in the last print statement - sometimes the .avi files do not properly download from google drive and must be done manually.*

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

import ticktalkpython.DebugLogger as log
import logging
log.set_base_logger_level(logging.ERROR)

test_name = "example_1_camera_sq"
simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg
# Out:
# TTPython.example_1_camera_sq:INFO:: setup sim
# TTPython.example_1_camera_sq:INFO:: setup ensembles
# TTPython.Ensemble:INFO:: Creating a new TTEnsemble: runtime-manager
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.example_1_camera_sq:INFO:: send graph inputs
# TTPython.Ensemble(runtime-manager):INFO:: Begin steady state
# TTPython.InputTokenProcess-runtime-manager:INFO:: run sim loop InputTokens
# TTPython.ExecutionProcess-runtime-manager:INFO:: run sim loop Execute
# TTPython.NetworkManager(runtime-manager):INFO:: run sim loop NetworkManager
# TTPython.RuntimeManager(runtime-manager):INFO:: run sim loop RuntimeManager
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x7a28d0ffb1c0 - type=RuntimeMsg.JoinTickTalkSystem; recipient=Recipient.ProcessRuntimeManager; payload={'name': 'runtime-manager', 'address': <ticktalkpython.Ensemble.TTEnsemble object at 0x7a28d0e98280>}>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.JoinTickTalkSystem
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ffae60 - type=NetMsg.AddRoutingTableEntry; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <ticktalkpython.Ensemble.TTEnsemble object at 0x7a28d0e98280>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.RuntimeManager(runtime-manager):INFO:: Sending PropagateRoutingTable message via <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x7a28d0ffb970>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0e98040 - type=NetMsg.PropagateRoutingTable; recipient=Recipient.ProcessNetwork; payload=runtime-manager>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.RuntimeManager(runtime-manager):INFO:: Completed JoinTickTalkSystem
# TTPython.Ensemble(runtime-manager):INFO:: Entering ensemble steady state (simulated)
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.PropagateRoutingTable
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.example_1_camera_sq:INFO:: Distribute Graph to ensembles
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x7a28d0ecd5d0 - type=RuntimeMsg.InstantiateAndMapGraph; recipient=Recipient.ProcessRuntimeManager; payload=<ticktalkpython.Graph.TTGraph object at 0x7a28d0e9b850>>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.InstantiateAndMapGraph
# TTPython.RuntimeManager(runtime-manager):INFO:: Send clocks to Ensemble(runtime-manager)
# TTPython.RuntimeManager(runtime-manager):INFO:: Input function is <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x7a28d0ffb970>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ecee60 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x7a28d0ecdfc0 - type=SyncMsg.AddClocks; recipient=Recipient.ProcessInputTokens; payload=[<TTClock ROOT ROOT>]>, <Message 0x7a28d0ecedd0 - type=ExecuteMsg.AddClocks; recipient=Recipient.ProcessExecute; payload=[<TTClock ROOT ROOT>]>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ecd690 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x7a28d0ece3e0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x7a28d0ece290>>, <Message 0x7a28d0ece2f0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x7a28d0ecead0>>, <Message 0x7a28d0ece500 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('camera_sampler-0', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_camera-1; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ecf5e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x7a28d0ecf220 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x7a28d0ecf400>>, <Message 0x7a28d0ecfd00 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x7a28d0ece1d0>>, <Message 0x7a28d0ecf2e0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_camera-1', [[<TTArcDestination Ens=runtime-manager; SQ-name=write_to_file-2; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ecf9a0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x7a28d0ecf550 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x7a28d0ecd930>>, <Message 0x7a28d0ece4a0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x7a28d0ecdcc0>>, <Message 0x7a28d0ecf100 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('write_to_file-2', [[]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.AddClocks
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ camera_sampler-0 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_camera-1 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ write_to_file-2 with firing rule TTFiringRuleType.Timed
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.AddClocks
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ camera_sampler-0
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_camera-1
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ write_to_file-2
# TTPython.example_1_camera_sq:INFO:: Sending token inputs
#
#
#
#
#
#
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x7a28d0ecf2e0 - type=RuntimeMsg.ExecuteGraphOnInputs; recipient=Recipient.ProcessRuntimeManager; payload=(<ticktalkpython.Graph.TTGraph object at 0x7a28d0e9b850>, {'trigger': 3735928559})>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.ExecuteGraphOnInputs
# TTPython.RuntimeManager(runtime-manager):INFO:: Prepare for execution of graph example_1_test on inputs {'trigger': 3735928559}
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x7a28d0ecc4c0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x7a28d0ecc9a0 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=camera_sampler-0.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ camera_sampler-0; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ camera_sampler-0
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ camera_sampler-0
# /content/ticktalkpython
# TTPython.ExecutionProcess-runtime-manager:INFO:: returned [<TTToken [[[array([[[ 58,  68, 115],
#         [ 57,  67, 114],
#         [ 57,  67, 114],
#         ...,
#         [ 62,  76, 130],
#         [ 63,  77, 131],
#         [ 64,  78, 132]],
#
#        [[ 58,  68, 115],
#         [ 57,  67, 114],
#         [ 57,  67, 114],
#         ...,
#         [ 61,  75, 129],
#         [ 62,  76, 130],
#         [ 62,  76, 130]],
#
#        [[ 60,  68, 115],
#         [ 59,  67, 114],
#         [ 59,  67, 114],
#         ...,
#         [ 60,  73, 123],
#         [ 59,  74, 124],
#         [ 59,  74, 124]],
#
#        ...,
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 71,  85, 144],
#         [ 71,  85, 144],
#         [ 71,  85, 144]],
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 73,  87, 146],
#         [ 73,  87, 146],
#         [ 73,  87, 146]],
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 74,  88, 147],
#         [ 74,  88, 147],
#         [ 74,  88, 147]]], dtype=uint8), 1517160744.4420073], [array([[[ 57,  63, 109],
#         [ 58,  64, 110],
#         [ 59,  65, 111],
#         ...,
#         [ 55,  73, 124],
#         [ 56,  75, 130],
#         [ 59,  78, 133]],
#
#        [[ 58,  64, 110],
#         [ 58,  64, 110],
#         [ 59,  65, 111],
#         ...,
#         [ 54,  72, 123],
#         [ 55,  74, 129],
#         [ 57,  76, 131]],
#
#        [[ 58,  63, 111],
#         [ 58,  63, 111],
#         [ 59,  64, 112],
#         ...,
#         [ 52,  70, 116],
#         [ 54,  73, 122],
#         [ 57,  76, 125]],
#
#        ...,
#
#        [[ 68,  76, 131],
#         [ 68,  76, 131],
#         [ 67,  75, 130],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]],
#
#        [[ 67,  75, 130],
#         [ 67,  75, 130],
#         [ 67,  75, 128],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]],
#
#        [[ 64,  72, 127],
#         [ 65,  73, 128],
#         [ 65,  73, 126],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]]], dtype=uint8), 1517160744.5750518], [array([[[ 61,  66, 116],
#         [ 60,  65, 115],
#         [ 59,  64, 114],
#         ...,
#         [ 69,  78, 129],
#         [ 71,  80, 131],
#         [ 73,  82, 133]],
#
#        [[ 60,  65, 115],
#         [ 59,  64, 114],
#         [ 58,  63, 113],
#         ...,
#         [ 65,  74, 125],
#         [ 67,  76, 127],
#         [ 68,  77, 128]],
#
#        [[ 61,  66, 116],
#         [ 60,  65, 115],
#         [ 59,  64, 114],
#         ...,
#         [ 59,  68, 119],
#         [ 63,  70, 121],
#         [ 64,  71, 122]],
#
#        ...,
#
#        [[ 62,  71, 126],
#         [ 66,  75, 130],
#         [ 68,  77, 132],
#         ...,
#         [ 74,  85, 146],
#         [ 74,  85, 146],
#         [ 74,  85, 146]],
#
#        [[ 60,  69, 124],
#         [ 64,  73, 128],
#         [ 67,  76, 131],
#         ...,
#         [ 74,  86, 145],
#         [ 74,  86, 145],
#         [ 74,  86, 145]],
#
#        [[ 59,  68, 123],
#         [ 64,  73, 128],
#         [ 66,  75, 130],
#         ...,
#         [ 74,  86, 145],
#         [ 74,  86, 145],
#         [ 74,  86, 145]]], dtype=uint8), 1517160744.6962125], [array([[[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 62,  78, 126],
#         [ 62,  78, 126],
#         [ 64,  80, 128]],
#
#        [[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 59,  75, 123],
#         [ 59,  75, 123],
#         [ 61,  77, 125]],
#
#        [[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 59,  70, 119],
#         [ 57,  71, 119],
#         [ 59,  73, 121]],
#
#        ...,
#
#        [[ 67,  73, 126],
#         [ 67,  73, 126],
#         [ 66,  74, 127],
#         ...,
#         [ 72,  86, 145],
#         [ 73,  86, 147],
#         [ 75,  88, 149]],
#
#        [[ 67,  75, 128],
#         [ 67,  75, 128],
#         [ 67,  75, 128],
#         ...,
#         [ 71,  85, 144],
#         [ 72,  85, 146],
#         [ 73,  86, 147]],
#
#        [[ 69,  77, 130],
#         [ 68,  76, 129],
#         [ 68,  76, 129],
#         ...,
#         [ 70,  84, 143],
#         [ 71,  84, 145],
#         [ 72,  85, 146]]], dtype=uint8), 1517160744.8158193], [array([[[ 59,  65, 125],
#         [ 58,  64, 124],
#         [ 57,  64, 121],
#         ...,
#         [ 68,  77, 132],
#         [ 67,  75, 132],
#         [ 66,  74, 131]],
#
#        [[ 59,  65, 125],
#         [ 58,  64, 124],
#         [ 57,  64, 121],
#         ...,
#         [ 64,  73, 128],
#         [ 65,  73, 130],
#         [ 65,  73, 130]],
#
#        [[ 59,  66, 123],
#         [ 58,  65, 122],
#         [ 57,  65, 120],
#         ...,
#         [ 59,  72, 122],
#         [ 61,  74, 124],
#         [ 62,  75, 125]],
#
#        ...,
#
#        [[ 68,  72, 140],
#         [ 68,  72, 140],
#         [ 64,  71, 138],
#         ...,
#         [ 75,  86, 155],
#         [ 75,  86, 155],
#         [ 74,  85, 154]],
#
#        [[ 67,  71, 141],
#         [ 67,  71, 141],
#         [ 64,  71, 138],
#         ...,
#         [ 75,  85, 156],
#         [ 75,  85, 156],
#         [ 74,  84, 155]],
#
#        [[ 67,  71, 141],
#         [ 67,  71, 141],
#         [ 63,  70, 137],
#         ...,
#         [ 75,  85, 156],
#         [ 75,  85, 156],
#         [ 74,  84, 155]]], dtype=uint8), 1517160744.94081]], 1694554156.505975] T:<TTTime [-9223372036854775807,9223372036854775807] C:<TTClock ROOT ROOT>>, Tag:None>]
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[[array([[[ 58,  68, 115],
#         [ 57,  67, 114],
#         [ 57,  67, 114],
#         ...,
#         [ 62,  76, 130],
#         [ 63,  77, 131],
#         [ 64,  78, 132]],
#
#        [[ 58,  68, 115],
#         [ 57,  67, 114],
#         [ 57,  67, 114],
#         ...,
#         [ 61,  75, 129],
#         [ 62,  76, 130],
#         [ 62,  76, 130]],
#
#        [[ 60,  68, 115],
#         [ 59,  67, 114],
#         [ 59,  67, 114],
#         ...,
#         [ 60,  73, 123],
#         [ 59,  74, 124],
#         [ 59,  74, 124]],
#
#        ...,
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 71,  85, 144],
#         [ 71,  85, 144],
#         [ 71,  85, 144]],
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 73,  87, 146],
#         [ 73,  87, 146],
#         [ 73,  87, 146]],
#
#        [[ 69,  75, 130],
#         [ 69,  75, 130],
#         [ 67,  75, 130],
#         ...,
#         [ 74,  88, 147],
#         [ 74,  88, 147],
#         [ 74,  88, 147]]], dtype=uint8), 1517160744.4420073], [array([[[ 57,  63, 109],
#         [ 58,  64, 110],
#         [ 59,  65, 111],
#         ...,
#         [ 55,  73, 124],
#         [ 56,  75, 130],
#         [ 59,  78, 133]],
#
#        [[ 58,  64, 110],
#         [ 58,  64, 110],
#         [ 59,  65, 111],
#         ...,
#         [ 54,  72, 123],
#         [ 55,  74, 129],
#         [ 57,  76, 131]],
#
#        [[ 58,  63, 111],
#         [ 58,  63, 111],
#         [ 59,  64, 112],
#         ...,
#         [ 52,  70, 116],
#         [ 54,  73, 122],
#         [ 57,  76, 125]],
#
#        ...,
#
#        [[ 68,  76, 131],
#         [ 68,  76, 131],
#         [ 67,  75, 130],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]],
#
#        [[ 67,  75, 130],
#         [ 67,  75, 130],
#         [ 67,  75, 128],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]],
#
#        [[ 64,  72, 127],
#         [ 65,  73, 128],
#         [ 65,  73, 126],
#         ...,
#         [ 76,  89, 145],
#         [ 76,  89, 145],
#         [ 76,  89, 145]]], dtype=uint8), 1517160744.5750518], [array([[[ 61,  66, 116],
#         [ 60,  65, 115],
#         [ 59,  64, 114],
#         ...,
#         [ 69,  78, 129],
#         [ 71,  80, 131],
#         [ 73,  82, 133]],
#
#        [[ 60,  65, 115],
#         [ 59,  64, 114],
#         [ 58,  63, 113],
#         ...,
#         [ 65,  74, 125],
#         [ 67,  76, 127],
#         [ 68,  77, 128]],
#
#        [[ 61,  66, 116],
#         [ 60,  65, 115],
#         [ 59,  64, 114],
#         ...,
#         [ 59,  68, 119],
#         [ 63,  70, 121],
#         [ 64,  71, 122]],
#
#        ...,
#
#        [[ 62,  71, 126],
#         [ 66,  75, 130],
#         [ 68,  77, 132],
#         ...,
#         [ 74,  85, 146],
#         [ 74,  85, 146],
#         [ 74,  85, 146]],
#
#        [[ 60,  69, 124],
#         [ 64,  73, 128],
#         [ 67,  76, 131],
#         ...,
#         [ 74,  86, 145],
#         [ 74,  86, 145],
#         [ 74,  86, 145]],
#
#        [[ 59,  68, 123],
#         [ 64,  73, 128],
#         [ 66,  75, 130],
#         ...,
#         [ 74,  86, 145],
#         [ 74,  86, 145],
#         [ 74,  86, 145]]], dtype=uint8), 1517160744.6962125], [array([[[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 62,  78, 126],
#         [ 62,  78, 126],
#         [ 64,  80, 128]],
#
#        [[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 59,  75, 123],
#         [ 59,  75, 123],
#         [ 61,  77, 125]],
#
#        [[ 59,  69, 118],
#         [ 58,  68, 117],
#         [ 57,  67, 116],
#         ...,
#         [ 59,  70, 119],
#         [ 57,  71, 119],
#         [ 59,  73, 121]],
#
#        ...,
#
#        [[ 67,  73, 126],
#         [ 67,  73, 126],
#         [ 66,  74, 127],
#         ...,
#         [ 72,  86, 145],
#         [ 73,  86, 147],
#         [ 75,  88, 149]],
#
#        [[ 67,  75, 128],
#         [ 67,  75, 128],
#         [ 67,  75, 128],
#         ...,
#         [ 71,  85, 144],
#         [ 72,  85, 146],
#         [ 73,  86, 147]],
#
#        [[ 69,  77, 130],
#         [ 68,  76, 129],
#         [ 68,  76, 129],
#         ...,
#         [ 70,  84, 143],
#         [ 71,  84, 145],
#         [ 72,  85, 146]]], dtype=uint8), 1517160744.8158193], [array([[[ 59,  65, 125],
#         [ 58,  64, 124],
#         [ 57,  64, 121],
#         ...,
#         [ 68,  77, 132],
#         [ 67,  75, 132],
#         [ 66,  74, 131]],
#
#        [[ 59,  65, 125],
#         [ 58,  64, 124],
#         [ 57,  64, 121],
#         ...,
#         [ 64,  73, 128],
#         [ 65,  73, 130],
#         [ 65,  73, 130]],
#
#        [[ 59,  66, 123],
#         [ 58,  65, 122],
#         [ 57,  65, 120],
#         ...,
#         [ 59,  72, 122],
#         [ 61,  74, 124],
#         [ 62,  75, 125]],
#
#        ...,
#
#        [[ 68,  72, 140],
#         [ 68,  72, 140],
#         [ 64,  71, 138],
#         ...,
#         [ 75,  86, 155],
#         [ 75,  86, 155],
#         [ 74,  85, 154]],
#
#        [[ 67,  71, 141],
#         [ 67,  71, 141],
#         [ 64,  71, 138],
#         ...,
#         [ 75,  85, 156],
#         [ 75,  85, 156],
#         [ 74,  84, 155]],
#
#        [[ 67,  71, 141],
#         [ 67,  71, 141],
#         [ 63,  70, 137],
#         ...,
#         [ 75,  85, 156],
#         [ 75,  85, 156],
#         [ 74,  84, 155]]], dtype=uint8), 1517160744.94081]], 1694554156.505975] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'camera_sampler-0', 'execute_time': 0, 'completion_time': 0}>]; source='camera_sampler-0'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ process_camera-1; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ process_camera-1
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ process_camera-1
# Started YOLO successfully...
# TTPython.ExecutionProcess-runtime-manager:INFO:: returned [<TTToken [[], 1517160744.94081, 1694554156.505975, 1694554158.9026968] T:<TTTime [-9223372036854775807,9223372036854775807] C:<TTClock ROOT ROOT>>, Tag:None>]
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[], 1517160744.94081, 1694554156.505975, 1694554158.9026968] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'process_camera-1', 'execute_time': 0, 'completion_time': 0}>]; source='process_camera-1'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ write_to_file-2; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ write_to_file-2
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ write_to_file-2
# TTPython.ExecutionProcess-runtime-manager:INFO:: returned [<TTToken 1 T:<TTTime [-9223372036854775807,9223372036854775807] C:<TTClock ROOT ROOT>>, Tag:None>]
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 1 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'write_to_file-2', 'execute_time': 0, 'completion_time': 0}>]; source='write_to_file-2'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x7a28d0e981c0>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x7a28d0ecc9d0 - type=RuntimeMsg.LogOutputToken; recipient=Recipient.ProcessRuntimeManager; payload=(<TTToken 1 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'write_to_file-2', 'runtime-manager')>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.LogOutputToken
# Processed cam_time:1517160744.94081, sys_proc_time:2.396721839904785 cam_timestamp: 1517160744.94081

# %% [markdown]
# **Step 4 - Compile Example 2 in Ticktalk:**
#  Here we will compile example 2 in Ticktalk. Run this cell block and you should see the graph of SQs shown as output. This step is similar to step 3 but we have changed the program to example 2.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

test_name = "example_2_camera_lidar_fusion_stream"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg
# Out:
# /content/ticktalkpython
# Compiling example_2_camera_lidar_fusion_stream
# TTPython.Compiler:INFO:: Compilation successful
# TTPython.Compiler:INFO:: Writing ./output/example_2_camera_lidar_fusion_stream.pickle
# Compiled output found at ./output/example_2_camera_lidar_fusion_stream.pickle

# %% [markdown]
# **Step 5 - Run Example 2 in Ticktalk:**
# Now that we have compiled example 2 within Ticktalk, lets run the code and see how it goes. Example 2 will spin up two different streamify nodes, one similar to example 1 that reads from a pre-recorded camera stream. This will then be sent to another SQ that will process the camera frames using a darknet based convolutional neural net called YoloV4. The second streamify node is opening frames from a recording of a LIDAR mounted next to the camera from example 1. This will be sent to another SQ that qill cluster the points seen by the lidar and then take the centroid of the clusters. Finally the output of both of these recognition pipelines (CAV locations in in x,y coordinates) will be ingested by a final SQ that will perform a sensor fusion on the matching frames and then writes the results to an output file. We will visualize the contents of this output file in the next step.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

# Run the graph that should have been compiled and saved in the previous block. This will fail if that has not been run yet. Note that jupyter is MUCH slower than running the same code from the terminal (2-3 orders of magnitude)
import ticktalkpython.DebugLogger as log
import logging
log.set_base_logger_level(logging.ERROR)

test_name = "example_2_camera_lidar_fusion_stream"
simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg --timeout 10000000000
# Out:
# TTPython.example_2_camera_lidar_fusion_stream:INFO:: setup sim
# TTPython.example_2_camera_lidar_fusion_stream:INFO:: setup ensembles
# TTPython.Ensemble:INFO:: Creating a new TTEnsemble: runtime-manager
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.example_2_camera_lidar_fusion_stream:INFO:: send graph inputs
# TTPython.Ensemble(runtime-manager):INFO:: Begin steady state
# TTPython.InputTokenProcess-runtime-manager:INFO:: run sim loop InputTokens
# TTPython.ExecutionProcess-runtime-manager:INFO:: run sim loop Execute
# TTPython.NetworkManager(runtime-manager):INFO:: run sim loop NetworkManager
# TTPython.RuntimeManager(runtime-manager):INFO:: run sim loop RuntimeManager
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x799aa34e4190 - type=RuntimeMsg.JoinTickTalkSystem; recipient=Recipient.ProcessRuntimeManager; payload={'name': 'runtime-manager', 'address': <ticktalkpython.Ensemble.TTEnsemble object at 0x799aa34e5f90>}>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.JoinTickTalkSystem
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa34e4400 - type=NetMsg.AddRoutingTableEntry; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <ticktalkpython.Ensemble.TTEnsemble object at 0x799aa34e5f90>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.RuntimeManager(runtime-manager):INFO:: Sending PropagateRoutingTable message via <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x799aa34e4220>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa34e55a0 - type=NetMsg.PropagateRoutingTable; recipient=Recipient.ProcessNetwork; payload=runtime-manager>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.RuntimeManager(runtime-manager):INFO:: Completed JoinTickTalkSystem
# TTPython.Ensemble(runtime-manager):INFO:: Entering ensemble steady state (simulated)
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.PropagateRoutingTable
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.example_2_camera_lidar_fusion_stream:INFO:: Distribute Graph to ensembles
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x799aa34e55a0 - type=RuntimeMsg.InstantiateAndMapGraph; recipient=Recipient.ProcessRuntimeManager; payload=<ticktalkpython.Graph.TTGraph object at 0x799aa34e5540>>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.InstantiateAndMapGraph
# TTPython.RuntimeManager(runtime-manager):INFO:: Send clocks to Ensemble(runtime-manager)
# TTPython.RuntimeManager(runtime-manager):INFO:: Input function is <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x799aa34e4220>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349ce20 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349c2b0 - type=SyncMsg.AddClocks; recipient=Recipient.ProcessInputTokens; payload=[<TTClock ROOT ROOT>]>, <Message 0x799aa349cdf0 - type=ExecuteMsg.AddClocks; recipient=Recipient.ProcessExecute; payload=[<TTClock ROOT ROOT>]>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349c2e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349cfa0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa349e530>>, <Message 0x799aa349d1b0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa349ec20>>, <Message 0x799aa349d090 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-0', [[<TTArcDestination Ens=runtime-manager; SQ-name=COPY_TTTIME-7; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349d1e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349c3a0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e1000>>, <Message 0x799aa349cf70 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e1090>>, <Message 0x799aa349d3c0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('READ_TTCLOCK-1', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-5; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=VALUES_TO_TTTIME-6; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349d300 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349d3f0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa348a980>>, <Message 0x799aa349d210 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa348aad0>>, <Message 0x799aa349d450 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-2', [[<TTArcDestination Ens=runtime-manager; SQ-name=MULT-4; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349d660 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349d750 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa348a5f0>>, <Message 0x799aa349d360 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa348a4a0>>, <Message 0x799aa349d570 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-3', [[<TTArcDestination Ens=runtime-manager; SQ-name=MULT-4; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349ed70 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349d5a0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa348ab90>>, <Message 0x799aa349d630 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e0b50>>, <Message 0x799aa349d8d0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('MULT-4', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-5; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349d810 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349d870 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e0c10>>, <Message 0x799aa349d6c0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e1030>>, <Message 0x799aa349eda0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('ADD-5', [[<TTArcDestination Ens=runtime-manager; SQ-name=VALUES_TO_TTTIME-6; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349edd0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349eef0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa3489de0>>, <Message 0x799aa349d7e0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa348a230>>, <Message 0x799aa349ef20 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('VALUES_TO_TTTIME-6', [[<TTArcDestination Ens=runtime-manager; SQ-name=COPY_TTTIME-7; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f0d0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349ff40 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e3f70>>, <Message 0x799aa349ee60 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa349e290>>, <Message 0x799aa349f010 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('COPY_TTTIME-7', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-9; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-10; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-15; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-16; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f580 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349ff10 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e2bc0>>, <Message 0x799aa349f0a0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e2680>>, <Message 0x799aa349fc10 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-8', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-9; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-10; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=2>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f400 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349fd30 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e3790>>, <Message 0x799aa349fe20 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e3b80>>, <Message 0x799aa349fd60 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('camera_sampler-9', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_camera-11; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349fdc0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f550 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e2a10>>, <Message 0x799aa349fc70 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e24a0>>, <Message 0x799aa349f4f0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('lidar_sampler-10', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_lidar-12; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f640 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f430 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e3730>>, <Message 0x799aa349f4c0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e3ee0>>, <Message 0x799aa349f1c0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_camera-11', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f190 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f1f0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e00d0>>, <Message 0x799aa349f610 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e0760>>, <Message 0x799aa349f5b0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_lidar-12', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349f6a0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f340 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e33d0>>, <Message 0x799aa349f100 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e3700>>, <Message 0x799aa349f820 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('local_fusion-13', [[<TTArcDestination Ens=runtime-manager; SQ-name=global_fusion-20; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349fb20 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f730 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e2cb0>>, <Message 0x799aa349f6d0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e23b0>>, <Message 0x799aa349f940 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-14', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-15; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-16; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-19; Port=2>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa349fa00 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349f970 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e22f0>>, <Message 0x799aa349fb80 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e1960>>, <Message 0x799aa349f9a0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('camera_sampler-15', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_camera-17; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# /content/ticktalkpython
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326dea0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa349faf0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e1900>>, <Message 0x799aa326dc60 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e1600>>, <Message 0x799aa326ddb0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('lidar_sampler-16', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_lidar-18; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326e0b0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa326dcf0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e2260>>, <Message 0x799aa326da80 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e1c60>>, <Message 0x799aa326dff0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_camera-17', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-19; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326db40 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa326f760 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e04f0>>, <Message 0x799aa326da50 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e11e0>>, <Message 0x799aa326e020 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_lidar-18', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-19; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326e200 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa326c460 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e1d20>>, <Message 0x799aa326e1d0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e2200>>, <Message 0x799aa326f700 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('local_fusion-19', [[<TTArcDestination Ens=runtime-manager; SQ-name=global_fusion-20; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326f820 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa326dae0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa34e35e0>>, <Message 0x799aa326df60 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34e2f20>>, <Message 0x799aa326f730 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('global_fusion-20', [[<TTArcDestination Ens=runtime-manager; SQ-name=write_to_file-21; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa326fa00 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x799aa326c520 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x799aa3489930>>, <Message 0x799aa326f6a0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x799aa34898d0>>, <Message 0x799aa326e260 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('write_to_file-21', [[]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.AddClocks
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-0 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ READ_TTCLOCK-1 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-2 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-3 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ MULT-4 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ ADD-5 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ VALUES_TO_TTTIME-6 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ COPY_TTTIME-7 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-8 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ camera_sampler-9 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ lidar_sampler-10 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_camera-11 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_lidar-12 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ local_fusion-13 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-14 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ camera_sampler-15 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ lidar_sampler-16 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_camera-17 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_lidar-18 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ local_fusion-19 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ global_fusion-20 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ write_to_file-21 with firing rule TTFiringRuleType.Timed
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.AddClocks
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-0
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ READ_TTCLOCK-1
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-2
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-3
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ MULT-4
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ ADD-5
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ VALUES_TO_TTTIME-6
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ COPY_TTTIME-7
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-8
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ camera_sampler-9
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ lidar_sampler-10
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_camera-11
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_lidar-12
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ local_fusion-13
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-14
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ camera_sampler-15
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ lidar_sampler-16
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_camera-17
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_lidar-18
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ local_fusion-19
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ global_fusion-20
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ write_to_file-21
# TTPython.example_2_camera_lidar_fusion_stream:INFO:: Sending token inputs
#
#
#
#
#
#
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x799aa3293ca0 - type=RuntimeMsg.ExecuteGraphOnInputs; recipient=Recipient.ProcessRuntimeManager; payload=(<ticktalkpython.Graph.TTGraph object at 0x799aa34e5540>, {'trigger': 3735928559})>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.ExecuteGraphOnInputs
# TTPython.RuntimeManager(runtime-manager):INFO:: Prepare for execution of graph streamify_test on inputs {'trigger': 3735928559}
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa32935b0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa3293f40 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=CONST-0.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa32901f0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa3293220 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=READ_TTCLOCK-1.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa32929e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa3292cb0 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=CONST-2.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa32937c0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa3293970 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=CONST-3.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa32935e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa32930a0 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=CONST-8.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x799aa3290250 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <Message 0x799aa32930d0 - type=SyncMsg.InputToken; recipient=Recipient.ProcessInputTokens; payload=<TTToken 3735928559 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=CONST-14.p=0.e=runtime-manager>>>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ CONST-0; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ CONST-0
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ READ_TTCLOCK-1; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ READ_TTCLOCK-1
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ CONST-2; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ CONST-2
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ CONST-3; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ CONST-3
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ CONST-8; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ CONST-8
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ CONST-14; Removing everything with time intervals older than -9223372036884775807
# TTPython.SQSync:INFO:: New Execution context for SQ CONST-14
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ CONST-0
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 1 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'CONST-0', 'execute_time': 0, 'completion_time': 0}>]; source='CONST-0'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ READ_TTCLOCK-1
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 0 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'READ_TTCLOCK-1', 'execute_time': 0, 'completion_time': 0}>]; source='READ_TTCLOCK-1'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ CONST-2
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 300 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'CONST-2', 'execute_time': 0, 'completion_time': 0}>]; source='CONST-2'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ CONST-3
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 2500000 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'CONST-3', 'execute_time': 0, 'completion_time': 0}>]; source='CONST-3'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ CONST-8
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 0 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'CONST-8', 'execute_time': 0, 'completion_time': 0}>]; source='CONST-8'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ CONST-14
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken 1 T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (-9223372036854775807,9223372036854775807)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'CONST-14', 'execute_time': 0, 'completion_time': 0}>]; source='CONST-14'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# ...
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Timed retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.TimedInput
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ lidar_sampler-10
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[0.0, 0.0, 0.0613464, 27, 1517160747.8160422], [[-12.254853918814726, 0.05983668198812069], [-12.246614665217253, 0.17039390155086448], [-12.23837555534624, 0.2809525338978621], [-12.230042338182855, 0.3912826296360021], [-12.222028960438218, 0.4987233002472588], [-12.21382513558357, 0.6090291925573087], [-12.205517313371615, 0.7194025319567269], [-12.19731804546863, 0.8296280779272803], [-12.189246017795487, 0.9369079771551039], [-12.180792318062924, 1.0504163480350384], [-12.172723180572095, 1.1582131320110258], [-12.164316298836702, 1.2687186732509894], [-12.122681529732807, 1.8190555485402535], [-12.11565887393557, 1.9254280927695724], [-7.679223757140416, 2.089719215150741], [-4.417295103703714, 2.0553047774953477], [-4.310894151968254, 2.0511857767218222], [-4.215237910159945, 2.0521378836838475], [-4.124356094440799, 2.053756001658677], [-4.02994501086974, 2.052515727166565], [-3.942297802655843, 2.0503122014159], [-3.8527768789668495, 2.048856623411814], [-3.772367816773971, 2.0501526030683626], [-3.7192712534291763, 2.0646274611695357], [-3.6248944225958, 2.053358144585076], [-3.5456345085403984, 2.050638558290438], [-2.2170925270857507, 1.5614206844859324], [-2.1975028877493297, 1.5765353085907585], [-2.3156328174279053, 1.7567493318202518], [-2.2913244936427146, 1.8376550015802633], [-2.313032596673939, 1.8883266690972236], [-2.3511848323813567, 1.9557154564199395], [-2.348551962337502, 1.9881461230504833], [-2.3348166357445557, 2.0122175902099837], [-2.3060818302452177, 2.0245604234778636], [-2.2743067762728644, 2.0310313497086474], [-2.2369141502033814, 2.0347744963557717], [-2.2018700705093495, 2.037897994673716], [-2.1693495202039, 2.0449678413342127], [-2.140953968081243, 2.0533823381575043], [-2.1295610654116914, 2.0794482954819102], [-2.1262783766205136, 2.1145925855152417], [-2.131211273921328, 2.1563559581642897], [-2.123074191425173, 2.1870168857611376], [-2.117515951325207, 2.220051232805969], [-2.0932106784878206, 2.3147864253672643], [-2.090721189335346, 2.3550413119230407], [-2.1277133116832676, 2.439667228493637], [-2.115355936302721, 2.4700270088298306], [-1.848135503720366, 2.4970451450240683], [-1.9245343656210756, 2.698372837923529], [-1.8890838504832608, 2.7005434234507946], [-1.8533122068613965, 2.6992735868745394], [-1.8172604550041729, 2.6993102229232613], [-1.7823146475518568, 2.6995332237300027], [-1.7473351477119268, 2.6978896674383366], [-1.7134800885170758, 2.6965126187643764], [-1.6805668187819927, 2.6980568915626995], [-1.6474815677007042, 2.699249113010215], [-1.615088023513614, 2.6984504990647666], [-1.5807385810792647, 2.6976180656066777], [-1.5487276917805224, 2.6968122202170797], [-1.5146030155523404, 2.695060287874792], [-1.4832568478843173, 2.693446053980714], [-1.4518474086445432, 2.692466412717552], [-1.4216128007148066, 2.6931151358313303], [-1.3910532505910602, 2.694066601630339], [-1.3607851322707576, 2.6935925860996233], [-1.3306218464133928, 2.6935151103061243], [-1.3009522813057932, 2.694595302798781], [-1.271523239459947, 2.694282690070454], [-1.241854949831596, 2.6935459092391136], [-1.2124004960890125, 2.6920667130446665], [-1.1817453351613247, 2.6904779515402923], [-1.1540005134709403, 2.6893107699573893], [-1.1257158539184648, 2.6897961550713503], [-1.098410904412955, 2.6903387611909984], [-1.069187568102416, 2.6891977515079177], [-1.0420068430934226, 2.688416441522124], [-1.0136471857406755, 2.687654811418313], [-0.986254177984609, 2.6870496320886788], [-0.9595537460484969, 2.687176938358227], [-0.9329309620655359, 2.6870525078642347], [-0.9050180566536816, 2.6866963762269074], [-0.878098679114532, 2.686736633508635], [-0.8521972329702727, 2.6865991265013487], [-0.8256473915094898, 2.6860797823209897], [-0.7997455962 ...
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ process_lidar-12; Removing everything with time intervals older than 178750000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ process_lidar-12
# TTPython.ExecutionProcess-runtime-manager:INFO:: Retriggering: <TTToken None T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (208750000,9223372036854775807)>, Tag:<TTTag: u=u1.sq=process_lidar-12.p=1.e=runtime-manager>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[0.0, 0.0, 0.0613464, 27, 1517160747.8160422], [[-4.186723141842829, 2.1692024843952096], [-2.453112523778862, 1.705892222431941], [-2.3809085391868017, 2.2827023947930174], [-0.7862415581359434, 2.9277361518228], [0.5635755539353668, 0.8736074646211511], [4.55271415328815, 2.188955292869425], [0.9472649686315202, -0.011977894885859246], [4.838094711534591, -0.707458753652481], [4.1645139260857675, -1.209895383256179], [2.6883701231354546, -1.5795043020488873], [2.210345327757418, -3.2334956761912585], [1.3657160718706187, -3.4638010892151363], [0.6219903697080313, -6.41328812991563], [-0.7655514249597495, -1.3930568258602722], [-5.023442670226508, -1.8917772557311041], [2.349485677828729, -2.827877222682355], [4.820188792331911, 1.2411361320856054], [3.9274034144069323, 2.7930472147016085], [4.3327889887479305, 2.7740801267010236]], 1517160747.8321707, 1694554530.6454966, 1694554530.7321322] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (208750000,211250000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'process_lidar-12', 'execute_time': 210000000, 'completion_time': 210000000}>]; source='process_lidar-12'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ local_fusion-13; Removing everything with time intervals older than 178750000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ local_fusion-13
# TTPython.ExecutionProcess-runtime-manager:INFO:: Retriggering: <TTToken None T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (208750000,9223372036854775807)>, Tag:<TTTag: u=u1.sq=local_fusion-13.p=3.e=runtime-manager>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[], 1517160747.8165593, [-0.75, 0.0, 0.0613464, 27, 1517160747.8160422], [1694554529.067736, 1694554530.6454966, 1694554530.6052332, 1694554530.7321322, 1694554531.1381238]] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (208750000,211250000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'local_fusion-13', 'execute_time': 210000000, 'completion_time': 210000000}>]; source='local_fusion-13'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Timed retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.TimedInput
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ camera_sampler-15
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [array([[[138, 111, 170],
#         [140, 113, 172],
#         [144, 115, 174],
#         ...,
#         [255, 254, 253],
#         [255, 253, 252],
#         [252, 250, 249]],
#
#        [[147, 120, 179],
#         [147, 120, 179],
#         [149, 120, 179],
#         ...,
#         [255, 254, 253],
#         [255, 254, 253],
#         [255, 254, 253]],
#
#        [[151, 125, 182],
#         [151, 125, 182],
#         [152, 124, 181],
#         ...,
#         [255, 251, 255],
#         [255, 254, 253],
#         [254, 252, 251]],
#
#        ...,
#
#        [[156, 135, 196],
#         [156, 135, 196],
#         [156, 135, 196],
#         ...,
#         [188, 159, 220],
#         [189, 160, 219],
#         [190, 161, 220]],
#
#        [[158, 138, 195],
#         [158, 138, 195],
#         [158, 138, 195],
#         ...,
#         [189, 159, 218],
#         [192, 159, 219],
#         [193, 160, 220]],
#
#        [[160, 140, 197],
#         [160, 140, 197],
#         [160, 140, 197],
#         ...,
#         [189, 159, 218],
#         [192, 159, 219],
#         [193, 160, 220]]], dtype=uint8), 1517160747.8165593, 1694554531.1740787] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (208750000,211250000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'camera_sampler-15', 'execute_time': 210000000, 'completion_time': 210000000}>]; source='camera_sampler-15'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x799aa34e5f60>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ process_camera-17; Removing everything with time intervals older than 178750000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ process_camera-17
# TTPython.executeProcess:INFO:: Caught BaseException
# Traceback (most recent call last):
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 336, in run_sim
#     self.handle_message(next_msg)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 438, in handle_message
#     self.execute(execution_context)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 802, in execute
#     return_token_list = sq_execute.function(
#   File "/content/ticktalkpython/ticktalkpython/SQ.py", line 771, in wrapper
#     return_value = function(*token_values, **kwargs)
#   File "", line 24, in process_camera
#   File "/content/ticktalkpython/libraries/camera_recognition.py", line 603, in processCameraFrame
#     coordinates, timestamp = self.yolo.readFrame(frame_read, cam_time_data)
#   File "/content/ticktalkpython/libraries/camera_recognition.py", line 453, in readFrame
#     detections = darknet.detect_image((self.network), (self.class_names), (self.darknet_image), thresh=0.25)
#   File "/content/darknet/darknet.py", line 246, in detect_image
#     predict_image(network, image)
# KeyboardInterrupt
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Timed retrigger firing rule call
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in run_sim(self, sim)
#     198                     try:
# --> 199                         self.handle_message(next_msg)
#     200                     except BaseException:
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in handle_message(self, msg)
#     290             self.logger.debug(f'Input token: {token}')
# --> 291             self.find_sq_and_sync(token)
#     292             #if synchronization completed, then a message will be send in the
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in find_sq_and_sync(self, token)
#     416                 Recipient.ProcessExecute)
# --> 417             self.input_execute_func(execution_message)
#     418
#
# /content/ticktalkpython/ticktalkpython/ExecuteProcess.py in input_msg(self, message)
#     283                 and self.sim.active_process != self.sim_process):
# --> 284             self.sim_process.interrupt()
#     285
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in interrupt(self, cause)
#     377         """
# --> 378         Interruption(self, cause)
#     379
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in __init__(self, process, cause)
#     285         if process._value is not PENDING:
# --> 286             raise RuntimeError(
#     287                 f'{process} has terminated and cannot be interrupted.'
#
# RuntimeError: <Process(run_sim) object at 0x799aa34e4430> has terminated and cannot be interrupted.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/simulate.py in <module>
#     108
#     109 if __name__ == "__main__":
# --> 110     main()
#
# /content/ticktalkpython/simulate.py in main()
#     104     rtm.manager_ensemble.enter_steady_state(timeout=timeout)
#     105
# --> 106     sim.run(until=timeout)
#     107
#     108
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     252         try:
#     253             while True:
# --> 254                 self.step()
#     255         except StopSimulation as exc:
#     256             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     204             exc = type(event._value)(*event._value.args)
#     205             exc.__cause__ = event._value
# --> 206             raise exc
#     207
#     208     def run(
#
# RuntimeError: <Process(run_sim) object at 0x799aa34e4430> has terminated and cannot be interrupted.

# %% [markdown]
# **Step 6 - Display Example 2 Data:**
# The data from example 1 was fairly easy to look at as there was only a single other vehicle in the scene that it was detecting. However example 2 has many more detections from the LIDAR. Therefore we have created a display function that reads in the output from example 2 and will display it on a 2D graph.

# %%
import matplotlib.pyplot as plt
import json

# define an empty list
data = []

# open file and read the content in a list
with open('/content/ticktalkpython/output/example_2_output.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentData = line[:-1]

        # add item to the list
        data.append(json.loads(currentData))

x = []
y = []
for frame in data:
  #print(frame)
  results = frame[0]
  for item in results:
    x.append(item[0])
    y.append(item[1])

plt.plot(x, y, 'o', color='black');
plt.show()

# %% [markdown]
# **Step 7 - Compile and Run Example 2 in Ticktalk w/ Non-Achievable Timing:**
#
# *Part 1:* Lets go into the source code and try to change some timing parameters for TTPython. The first one we should change is TTPeriod. This construct dictates the period at which our streams will send new data. In the original example 2 this was set to 750000 or 750ms. This is because in the free tier of Google Colab the entire recognition pipeline takes about 700ms to execute so we add a little extra space to make sure that it always has enough processing time. Go change this number to something else like TTPeriod=250000. After you change this value in examples/example_2_camera_lidar_fusion_stream.py, run the following step to check the results. The telltale sign of a deadline that is too short will be that the sensor fusion SQ will not be firing when you set the log level to WARN. This is because if either the LIDAR or CAMERA don't arrive within the time window then the Local Fusion SQ will not fire as often. A telltale sign of a deadline that is too long will be too much extra wait time between the SQ that writes to the file and the next subsequent streamify node firing. This again is visible if the log level is set to Warn so that the SQ firings are shown in the console output.
#
# *Part 2:* Next we should take a look at another construct, TTDataIntervalWidth. This specifies the time range at which TTPython will match the outputs of two streams and consider them to be match-able. In this example our default value is TTDataIntervalWidth=250000 or 250ms because +-250ms is enough range that the LIDAR and Camera streams will be properly matched even taking into account that LIDAR recognition and Camera recognition must run before the matching stage. Lets make this not work then, because camera recognition takes around 300ms on Google collab using an interval width like TTDataIntervalWidth=125000 should cause none of our streams to match, and thus will not allow the local_fusion node to fire! Conversely if the TTDataIntervalWidth is too large then steams with timesteps that are very far apart may be matched. This is very hard to see in this example as we do not specifically print the timestamps of the data that was matched but some simple changes to the code in the sensor fusion SQ could do it. Make sure to change TTPeriod back to 750000 before messing with the TTDataIntervalWidth so we are only testing one construct at a time.
#
# *Part 3:* Now it is your turn to go crazy and try combinations of TTPeriod and TTDataIntervalWidth to see what happens. Try answering the following questions:
#
# 1.   What is the smallest you can make TTDataIntervalWidth and the application still works? The application still working is defined as the sensor fusion node firing when you have the logging level set to warn because if the interval is too small the streams will not be matched and therefore the sensor fusion wont fire.
# 2.   What is the smallest you can make TTPeriod and the application still works? Is there a number where it works sometimes but not all the time - i.e. you are within the timing "jitter" zone? This zone will be an area where sometimes the write to file SQ fires and sometimes it does not, which should be visible with logging set to warn.
#
# When you are done answering these questions, just make sure to change the values back to the default values of TTDataIntervalWidth=250000 and TTPeriod=750000.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

test_name = "example_2_camera_lidar_fusion_stream"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg

# %cd /content/ticktalkpython/

import ticktalkpython.DebugLogger as log
import logging
log.set_base_logger_level(logging.ERROR)

# Remove our old output file
# !rm /content/ticktalkpython/output/example_2_output.txt

#stm.streaming_merge_sim(filename='./output/' + test_name + '.pickle')
simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg --timeout 10000000000
# Out:
# /content/ticktalkpython
# Compiling example_2_camera_lidar_fusion_stream
# /content/ticktalkpython
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# Started YOLO successfully...
# Started LIDAR successfully...
# Traceback (most recent call last):
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 329, in run_sim
#     self.handle_message(next_msg)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 430, in handle_message
#     self.execute(execution_context)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 792, in execute
#     return_token_list = sq_execute.function(
#   File "/content/ticktalkpython/ticktalkpython/SQ.py", line 782, in wrapper
#     return_value = function(*token_values, **kwargs)
#   File "", line 15, in process_lidar
#   File "/content/ticktalkpython/libraries/lidar_recognition.py", line 314, in processLidarFrame
#     y_pred = db.fit_predict(array)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/cluster/_dbscan.py", line 446, in fit_predict
#     self.fit(X, sample_weight=sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/cluster/_dbscan.py", line 407, in fit
#     core_samples = np.asarray(n_neighbors >= self.min_samples, dtype=np.uint8)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in run_sim(self, sim)
#     198                     try:
# --> 199                         self.handle_message(next_msg)
#     200                     except BaseException:
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in handle_message(self, msg)
#     290             self.logger.debug(f'Input token: {token}')
# --> 291             self.find_sq_and_sync(token)
#     292             #if synchronization completed, then a message will be send in the
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in find_sq_and_sync(self, token)
#     416                 Recipient.ProcessExecute)
# --> 417             self.input_execute_func(execution_message)
#     418
#
# /content/ticktalkpython/ticktalkpython/ExecuteProcess.py in input_msg(self, message)
#     276             self.logger.log(2, 'Interrupting!: t=%f', self.sim.now)
# --> 277             self.sim_process.interrupt()
#     278
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in interrupt(self, cause)
#     377         """
# --> 378         Interruption(self, cause)
#     379
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in __init__(self, process, cause)
#     285         if process._value is not PENDING:
# --> 286             raise RuntimeError(
#     287                 f'{process} has terminated and cannot be interrupted.'
#
# RuntimeError: <Process(run_sim) object at 0x7ef81db083a0> has terminated and cannot be interrupted.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/simulate.py in <module>
#      97
#      98 if __name__ == "__main__":
# ---> 99     main()
#
# /content/ticktalkpython/simulate.py in main()
#      93     rtm.manager_ensemble.enter_steady_state(timeout=timeout)
#      94
# ---> 95     sim.run(until=timeout)
#      96
#      97
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     252         try:
#     253             while True:
# --> 254                 self.step()
#     255         except StopSimulation as exc:
#     256             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     204             exc = type(event._value)(*event._value.args)
#     205             exc.__cause__ = event._value
# --> 206             raise exc
#     207
#     208     def run(
#
# RuntimeError: <Process(run_sim) object at 0x7ef81db083a0> has terminated and cannot be interrupted.

# %% [markdown]
# **Step 8 - Compile Example 3 in Ticktalk:**
#  Here we will compile example 3 in Ticktalk. Run this cell block and you should see the graph of SQs shown as output. This step is similar to step 5 but we have changed the program to example 3. Example 3 adds in the global fusion steps as well as ensemble construct which explained better in step 9.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/


test_name = "example_3_two_cavs_fusion_stream"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg
# Out:
# /content/ticktalkpython
# Compiling example_3_two_cavs_fusion_stream

# %% [markdown]
# **Step 9 - Run Example 3 in Ticktalk:**
# Now that we have compiled example 3 within Ticktalk, lets run the code and see how it goes. Example 3 will use same code from example 2, but will create 2 copies of it that read in from different data files. After the local fusion is done (same as example 2) the output from each CAV is sent to the global fusion function (which is just a wrapper for a second call of local fusion) where it is fused together to get a global picture of what is going on. You may also notice some new concepts are introduced here - ensembles. Using similar syntax to the Python "with" construct we can designate sections of code to will be deployed to specifically names ensembles - such as "CAV0", "CAV1" and "RSU" in this example.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

# Run the streaming_merge graph that should have been compiled and saved in the previous block. This will fail if that has not been run yet. Note that jupyter is MUCH slower than running the same code from the terminal (2-3 orders of magnitude)

import ticktalkpython.DebugLogger as log
import logging
log.set_base_logger_level(logging.ERROR)

test_name = "example_3_two_cavs_fusion_stream"
simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg --timeout 10000000000
# Out:
# /content/ticktalkpython
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# Started YOLO successfully...
# Started LIDAR successfully...
# Started FUSION successfully...
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# Started YOLO successfully...
# Started LIDAR successfully...
# Started FUSION successfully...
# Started FUSION successfully...
# Processed global fusion @  1689367071.3099704
# Processed global fusion @  1689367072.3037279
# Processed global fusion @  1689367073.4109416
# Processed global fusion @  1689367074.4269125
# Processed global fusion @  1689367075.5367577
# Processed global fusion @  1689367076.533923
# Processed global fusion @  1689367077.9301946
# Processed global fusion @  1689367079.342698
# Processed global fusion @  1689367081.539802
# Processed global fusion @  1689367083.9216757
# Processed global fusion @  1689367099.1833832
# Processed global fusion @  1689367122.2937877
# Processed global fusion @  1689367143.0226736
# Processed global fusion @  1689367164.7585132
# Cleaning track  27
# Cleaning track  27
# Processed global fusion @  1689367183.7194242
# Cleaning track  27
# Processed global fusion @  1689367203.8156142
# Cleaning track  27
# Processed global fusion @  1689367225.5086348
# Cleaning track  27
# Cleaning track  28
# Processed global fusion @  1689367248.3586583
# Cleaning track  28
# Processed global fusion @  1689367271.1435127
# Cleaning track  28
# Processed global fusion @  1689367294.0280895
# Cleaning track  28
# Processed global fusion @  1689367315.473814
# Cleaning track  28
# Processed global fusion @  1689367338.5403404
# Cleaning track  28
# Processed global fusion @  1689367361.4211786
# Cleaning track  28
# Processed global fusion @  1689367383.747115
# Cleaning track  28
# Processed global fusion @  1689367404.9362874
# Cleaning track  28
# Processed global fusion @  1689367426.789447
# Cleaning track  28
# Processed global fusion @  1689367447.23583
# Cleaning track  28
# Processed global fusion @  1689367469.31965
# Cleaning track  28
# Processed global fusion @  1689367491.1044192
# Cleaning track  28
# Processed global fusion @  1689367512.5040615
# Cleaning track  28
# Processed global fusion @  1689367535.5500402
# Cleaning track  28
# Processed global fusion @  1689367558.5332534
# Cleaning track  28
# Processed global fusion @  1689367579.9946456
# Cleaning track  28
# Processed global fusion @  1689367601.8250093
# Cleaning track  28
# Processed global fusion @  1689367623.5091279
# Cleaning track  27
# Processed global fusion @  1689367642.0542414
# Cleaning track  26
# Processed global fusion @  1689367659.7585218
# Cleaning track  26
# Processed global fusion @  1689367678.8664145
# Cleaning track  26
# Processed global fusion @  1689367696.9942396
# Cleaning track  25
# Processed global fusion @  1689367715.066596
# Cleaning track  25
# Processed global fusion @  1689367731.5955162
# Cleaning track  25
# Processed global fusion @  1689367748.1206226
# Cleaning track  25
# Processed global fusion @  1689367765.1697032
# Cleaning track  23
# Processed global fusion @  1689367780.0557613
# Cleaning track  23
# Processed global fusion @  1689367796.899081
# Cleaning track  23
# Processed global fusion @  1689367813.4064417
# Cleaning track  26
# Processed global fusion @  1689367831.2362676
# Cleaning track  26
# Processed global fusion @  1689367849.3424091
# Cleaning track  26
# Processed global fusion @  1689367866.3608525
# Cleaning track  24
# Processed global fusion @  1689367880.6625547
# Cleaning track  24
# Processed global fusion @  1689367894.9575431
# Cleaning track  24
# Processed global fusion @  1689367913.2089317
# Processed global fusion @  1689367930.4687948
# Processed global fusion @  1689367952.4346483
# Processed global fusion @  1689367979.8616395
# Cleaning track  27
# Cleaning track  25
# Cleaning track  28
# Processed global fusion @  1689368000.4771078
# Cleaning track  28
# Processed global fusion @  1689368025.2282495
# Processed global fusion @  1689368050.9170156
# Cleaning track  31
# Processed global fusion @  1689368079.830984
# Cleaning track  30
# Processed global fusion @  1689368110.1940475
# Cleaning track  28
# Processed global fusion @  1689368131.68063
# Processed global fusion @  1689368153.5129943
# Processed global fusion @  1689368178.921745
# Processed global fusion @  1689368206.3034513
# Cleaning track  28
# Cleaning track  28
# Processed global fusion @  1689368228.3634126
# Cleaning track  28
# Processed global fusion @  1689368248.6316988
# Cleaning track  28
# Processed global fusion @  1689368270.4374745
# Cleaning track  28
# Processed global fusion @  1689368290.9497116
# Cleaning track  28
# Processed global fusion @  1689368312.869799
# Cleaning track  28
# Processed global fusion @  1689368334.6522808
# Cleaning track  28
# Processed global fusion @  1689368355.2175567
# Cleaning track  28
# Processed global fusion @  1689368377.1469529
# Cleaning track  28
# Processed global fusion @  1689368398.5905366
# Cleaning track  28
# Processed global fusion @  1689368422.4792702
# Processed global fusion @  1689368448.0832555
# Cleaning track  31
# Processed global fusion @  1689368478.636809
# Cleaning track  30
# Processed global fusion @  1689368507.4202976
# Processed global fusion @  1689368535.1427383
# Cleaning track  29
# Cleaning track  30
# Processed global fusion @  1689368560.7912776
# Cleaning track  30
# Processed global fusion @  1689368586.305453
# Cleaning track  30
# Processed global fusion @  1689368611.800813
# Cleaning track  30
# Processed global fusion @  1689368637.1989377
# Cleaning track  30
# Processed global fusion @  1689368662.280401
# Cleaning track  30
# Processed global fusion @  1689368686.5237992
# Cleaning track  28
# Processed global fusion @  1689368707.9345057
# Cleaning track  28
# Processed global fusion @  1689368730.583194
# Cleaning track  28
# Processed global fusion @  1689368751.299666
# Cleaning track  28
# Processed global fusion @  1689368771.541297
# Cleaning track  28
# Processed global fusion @  1689368791.7228284
# Cleaning track  28
# Processed global fusion @  1689368810.8659742
# Cleaning track  28
# Processed global fusion @  1689368831.0810142
# Cleaning track  28
# Processed global fusion @  1689368851.2378721
# Cleaning track  28
# Processed global fusion @  1689368870.4051476
# Cleaning track  28
# Processed global fusion @  1689368890.6909757
# Cleaning track  28
# Processed global fusion @  1689368910.0595446
# Cleaning track  28
# Processed global fusion @  1689368930.040237
# Cleaning track  28
# Processed global fusion @  1689368950.196903
# Cleaning track  28
# Processed global fusion @  1689368969.539684
# Cleaning track  28
# Processed global fusion @  1689368989.6048717
# Cleaning track  28
# Processed global fusion @  1689369009.681392
# Cleaning track  26
# Processed global fusion @  1689369025.8485692
# Cleaning track  26
# Processed global fusion @  1689369041.9799478
# Cleaning track  26
# Processed global fusion @  1689369060.105799
# Processed global fusion @  1689369077.893265
# Processed global fusion @  1689369099.6817842
# Cleaning track  26
# Cleaning track  27
# Processed global fusion @  1689369124.525777
# Cleaning track  27
# Cleaning track  30
# Processed global fusion @  1689369149.4720693
# Cleaning track  28
# Processed global fusion @  1689369170.8408897
# Cleaning track  28
# Processed global fusion @  1689369192.1897795
# Cleaning track  28
# Processed global fusion @  1689369212.4828377
# Cleaning track  28
# Processed global fusion @  1689369233.7016397
# Cleaning track  27
# Processed global fusion @  1689369253.2906158
# Cleaning track  27
# Processed global fusion @  1689369271.84196
# Cleaning track  27
# Processed global fusion @  1689369291.5520568
# Cleaning track  27
# Processed global fusion @  1689369310.4789515
# Cleaning track  27
# Processed global fusion @  1689369329.9020228
# Cleaning track  27
# Processed global fusion @  1689369349.6581917
# Cleaning track  27
# Processed global fusion @  1689369368.2367237
# Cleaning track  27
# Processed global fusion @  1689369387.984002
# Cleaning track  27
# Processed global fusion @  1689369406.943006
# Cleaning track  27
# Processed global fusion @  1689369427.2486584
# Cleaning track  27
# Processed global fusion @  1689369447.0634263
# Cleaning track  27
# Processed global fusion @  1689369466.00268
# Cleaning track  27
# Processed global fusion @  1689369485.5559595
# Cleaning track  27
# Processed global fusion @  1689369504.6349456
# Cleaning track  27
# Processed global fusion @  1689369524.0531394
# Cleaning track  27
# Processed global fusion @  1689369543.4899423
# Cleaning track  27
# Processed global fusion @  1689369561.0276546
# Cleaning track  26
# Processed global fusion @  1689369577.1843238
# Cleaning track  26
# Processed global fusion @  1689369594.195799
# Cleaning track  26
# Processed global fusion @  1689369610.3758533
# Cleaning track  26
# Processed global fusion @  1689369627.4587116
# Cleaning track  26
# Processed global fusion @  1689369643.822028
# Cleaning track  26
# Processed global fusion @  1689369659.861577
# Cleaning track  26
# Processed global fusion @  1689369676.9836652
# Cleaning track  26
# Processed global fusion @  1689369693.1727562
# Cleaning track  26
# Processed global fusion @  1689369709.6173887
# Cleaning track  26
# Processed global fusion @  1689369726.7805963
# Cleaning track  26
# Processed global fusion @  1689369742.9044454
# Cleaning track  26
# Processed global fusion @  1689369762.8404589
# Cleaning track  28
# Processed global fusion @  1689369781.9794307
# Cleaning track  26
# Processed global fusion @  1689369798.8583562
# Cleaning track  26
# Processed global fusion @  1689369814.857975
# Cleaning track  26
# Processed global fusion @  1689369831.0652497
# Cleaning track  24
# Processed global fusion @  1689369844.475706
# Cleaning track  24
# Processed global fusion @  1689369859.1805186
# Cleaning track  24
# Processed global fusion @  1689369872.5583155
# Cleaning track  24
# Processed global fusion @  1689369885.9073653
# Cleaning track  24
# Processed global fusion @  1689369899.5513098
# Cleaning track  24
# Processed global fusion @  1689369913.0847237
# Cleaning track  24
# Processed global fusion @  1689369926.6379976
# Cleaning track  24
# Processed global fusion @  1689369940.0639834
# Cleaning track  24
# Processed global fusion @  1689369956.8173304
# Processed global fusion @  1689369973.2197814
# Processed global fusion @  1689369997.275736
# Cleaning track  27
# Processed global fusion @  1689370023.2259536
# Cleaning track  28
# Cleaning track  28
# Processed global fusion @  1689370043.6075487
# Cleaning track  28
# Processed global fusion @  1689370063.226189
# Cleaning track  28
# Processed global fusion @  1689370083.6781785
# Cleaning track  28
# Processed global fusion @  1689370103.9757214
# Cleaning track  28
# Processed global fusion @  1689370123.2345076
# Cleaning track  26
# Processed global fusion @  1689370140.9470956
# Cleaning track  26
# Processed global fusion @  1689370157.0645216
# Cleaning track  26
# Processed global fusion @  1689370176.5905929
# Cleaning track  26
# Cleaning track  27
# Processed global fusion @  1689370195.198443
# Cleaning track  27
# Processed global fusion @  1689370214.8602724
# Cleaning track  27
# Processed global fusion @  1689370233.9433234
# Cleaning track  27
# Processed global fusion @  1689370253.1230159
# Cleaning track  27
# Processed global fusion @  1689370273.062185
# Cleaning track  26
# Processed global fusion @  1689370290.236095
# Cleaning track  26
# Processed global fusion @  1689370308.1231222
# Cleaning track  26
# Processed global fusion @  1689370325.173697
# Cleaning track  26
# Processed global fusion @  1689370342.4182818
# Cleaning track  26
# Processed global fusion @  1689370360.4585283
# Cleaning track  26
# Processed global fusion @  1689370377.5574841
# Cleaning track  26
# Processed global fusion @  1689370395.6587386
# Cleaning track  26
# Processed global fusion @  1689370412.7205944
# Cleaning track  26
# Processed global fusion @  1689370430.747889
# Cleaning track  26
# Processed global fusion @  1689370447.8834121
# Cleaning track  26
# Processed global fusion @  1689370465.7897267
# Cleaning track  26
# Processed global fusion @  1689370482.787549
# Cleaning track  26
# Processed global fusion @  1689370499.8113694
# Cleaning track  27
# Processed global fusion @  1689370518.6540446
# Cleaning track  27
# Processed global fusion @  1689370536.5493326
# Cleaning track  25
# Processed global fusion @  1689370552.2351048
# Cleaning track  25
# Processed global fusion @  1689370566.9779959
# Cleaning track  25
# Processed global fusion @  1689370581.6646562
# Cleaning track  25
# Processed global fusion @  1689370596.3760605
# Cleaning track  25
# Processed global fusion @  1689370613.0206213
# Cleaning track  23
# Processed global fusion @  1689370628.853046
# Cleaning track  23
# Processed global fusion @  1689370643.09987
# Cleaning track  25
# Processed global fusion @  1689370658.5814388
# Cleaning track  25
# Processed global fusion @  1689370673.8798192
# Cleaning track  25
# Processed global fusion @  1689370688.7847488
# Cleaning track  25
# Processed global fusion @  1689370703.6448643
# Cleaning track  25
# Processed global fusion @  1689370718.6263008
# Cleaning track  25
# Processed global fusion @  1689370734.215442
# Cleaning track  25
# Processed global fusion @  1689370749.060104
# Cleaning track  25
# Processed global fusion @  1689370766.004412
# Cleaning track  25
# Cleaning track  26
# Processed global fusion @  1689370784.1018527
# Cleaning track  26
# Processed global fusion @  1689370805.2507231
# Cleaning track  24
# Cleaning track  26
# Processed global fusion @  1689370822.25193
# Cleaning track  26
# Processed global fusion @  1689370839.4497461
# Cleaning track  26
# Processed global fusion @  1689370857.5307035
# Cleaning track  26
# Processed global fusion @  1689370874.580369
# Cleaning track  26
# Processed global fusion @  1689370892.7005243
# Cleaning track  26
# Processed global fusion @  1689370909.95848
# Cleaning track  26
# Processed global fusion @  1689370928.1443088
# Cleaning track  26
# Processed global fusion @  1689370945.2388952
# Cleaning track  26
# Processed global fusion @  1689370963.241481
# Cleaning track  26
# Processed global fusion @  1689370979.2896235
# Cleaning track  24
# Processed global fusion @  1689370993.520682
# Processed global fusion @  1689371007.0746071
# Processed global fusion @  1689371024.2327332
# Cleaning track  23
# Cleaning track  24
# Processed global fusion @  1689371037.8364468
# Cleaning track  24
# Processed global fusion @  1689371053.4916945
# Processed global fusion @  1689371069.5586066
# Processed global fusion @  1689371089.810116
# Cleaning track  25
# Cleaning track  26
# Processed global fusion @  1689371105.9320028
# Cleaning track  26
# Processed global fusion @  1689371123.5573096
# Cleaning track  26
# Processed global fusion @  1689371139.880726
# Cleaning track  26
# Processed global fusion @  1689371156.920442
# Cleaning track  26
# Processed global fusion @  1689371173.6080766
# Cleaning track  26
# Processed global fusion @  1689371189.7000299
# Cleaning track  26
# Processed global fusion @  1689371206.756636
# Cleaning track  26
# Processed global fusion @  1689371222.8038378
# Cleaning track  26
# Processed global fusion @  1689371238.778751
# Cleaning track  26
# Processed global fusion @  1689371255.8377159
# Cleaning track  26
# Processed global fusion @  1689371272.1821218
# Cleaning track  26
# Processed global fusion @  1689371288.2694764
# Cleaning track  26
# Processed global fusion @  1689371305.481794
# Cleaning track  26
# Processed global fusion @  1689371321.5946724
# Cleaning track  26
# Processed global fusion @  1689371338.056989
# Cleaning track  26
# Processed global fusion @  1689371354.8953886
# Cleaning track  26
# Processed global fusion @  1689371371.202994
# Cleaning track  26
# Processed global fusion @  1689371388.5409606
# Cleaning track  26
# Processed global fusion @  1689371404.7505672
# Cleaning track  26
# Processed global fusion @  1689371421.970932
# Processed global fusion @  1689371440.8400645
# Processed global fusion @  1689371462.8783457
# Cleaning track  30
# Processed global fusion @  1689371486.887042
# Cleaning track  26
# Cleaning track  27
# Processed global fusion @  1689371504.8300986
# Cleaning track  27
# Processed global fusion @  1689371523.5002043
# Cleaning track  27
# Processed global fusion @  1689371541.1548665
# Cleaning track  27
# Processed global fusion @  1689371560.0127196
# Cleaning track  27
# Processed global fusion @  1689371577.634421
# Cleaning track  27
# Processed global fusion @  1689371596.2934792
# Cleaning track  27
# Processed global fusion @  1689371614.2181869
# Cleaning track  27
# Processed global fusion @  1689371633.100191
# Cleaning track  27
# Processed global fusion @  1689371650.8592873
# Cleaning track  27
# Processed global fusion @  1689371669.580073
# Cleaning track  27
# Processed global fusion @  1689371690.7096224
# Processed global fusion @  1689371712.2259686
# Cleaning track  29
# Processed global fusion @  1689371737.4481385
# Cleaning track  29
# Processed global fusion @  1689371763.2288535
# Processed global fusion @  1689371783.1795454
# Cleaning track  27
# Processed global fusion @  1689371805.3459697
# Cleaning track  27
# Cleaning track  27
# Processed global fusion @  1689371823.539091
# Cleaning track  27
# Processed global fusion @  1689371842.5619516
# Cleaning track  23
# Processed global fusion @  1689371854.817065
# Cleaning track  23
# Processed global fusion @  1689371869.1526837
# Cleaning track  23
# Cleaning track  24
# Processed global fusion @  1689371883.3263144
# Cleaning track  24
# Processed global fusion @  1689371898.6975245
# Cleaning track  23
# Processed global fusion @  1689371911.7171853
# Cleaning track  23
# Processed global fusion @  1689371924.8042872
# Cleaning track  23
# Processed global fusion @  1689371937.9255064
# Cleaning track  23
# Processed global fusion @  1689371950.2335706
# Cleaning track  20
# Processed global fusion @  1689371962.1359062
# Processed global fusion @  1689371974.4334285
# Processed global fusion @  1689371989.4454007
# Cleaning track  26
# Processed global fusion @  1689372006.0292373
# Cleaning track  22
# Cleaning track  23
# Processed global fusion @  1689372018.7470708
# Cleaning track  23
# Processed global fusion @  1689372033.4788868
# Processed global fusion @  1689372051.3430696
# Cleaning track  28
# Processed global fusion @  1689372072.5489848
# Processed global fusion @  1689372087.2517974
# Processed global fusion @  1689372107.4612212
# Processed global fusion @  1689372126.5466487
# Cleaning track  25
# Cleaning track  25
# Processed global fusion @  1689372142.4168456
# Cleaning track  25
# Processed global fusion @  1689372157.141697
# Cleaning track  25
# Processed global fusion @  1689372178.3561888
# Processed global fusion @  1689372199.2090328
# Processed global fusion @  1689372226.169519
# Cleaning track  28
# Cleaning track  29
# Processed global fusion @  1689372247.351417
# Cleaning track  29
# Processed global fusion @  1689372269.3547275
# Cleaning track  29
# Processed global fusion @  1689372291.379556
# Cleaning track  29
# Processed global fusion @  1689372313.426906
# Cleaning track  29
# Processed global fusion @  1689372335.2887042
# Cleaning track  29
# Processed global fusion @  1689372356.473514
# Cleaning track  29
# Processed global fusion @  1689372378.5561707
# Cleaning track  29
# Processed global fusion @  1689372400.5807254
# Cleaning track  29
# Processed global fusion @  1689372422.6433353
# Cleaning track  29
# Processed global fusion @  1689372444.5215003
# Cleaning track  27
# Processed global fusion @  1689372462.323143
# Cleaning track  27
# Processed global fusion @  1689372481.0035434
# Cleaning track  27
# Processed global fusion @  1689372498.6770349
# Cleaning track  27
# Processed global fusion @  1689372517.4339235
# Cleaning track  27
# Processed global fusion @  1689372535.2306905
# Cleaning track  27
# Processed global fusion @  1689372553.9396257
# Cleaning track  27
# Processed global fusion @  1689372571.8677251

# %% [markdown]
# **Step 10 - Compile Example 4 in Ticktalk:**
#  Here we will compile example 4 in Ticktalk. Run this cell block and you should see the graph of SQs shown as output. This step is similar to step 8 but we have changed the program to example 4. Example 4 adds in the PlanB deadline construct.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

test_name = "example_4_two_cavs_fusion_stream_deadline_ensemble"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg
# Out:
# /content/ticktalkpython
# Compiling example_4_two_cavs_fusion_stream_deadline_ensemble

# %% [markdown]
# **Step 11 - Run Example 4 in Ticktalk:**
# Now that we have compiled example 4 within Ticktalk, lets run the code and see how it goes. Example 4 seems almost identical to example 3. However one major thing has changed - we have added deadlines. Actual Cyber Physical Systems don't always meet their deadlines - many times due to uncontrollable external variables like network speed or sensor failure. When that happens we need a mechanism to make sure that time critical SQs still get executed and that appropriate action can be taken to mitigate damage. In the case of driving a CAV this could mean an emergency stopping maneuver. In the case of our application we have been working on, we have multiple inputs to the global fusion and we want to make sure it still runs even when one or even both of the locally fused CAV sensor data does not arrive in time. To do this we add in the TTPython PlanB deadline construct to detect the missed deadline and create a new array that is empty to send in its place. The global fusion application knows how to handle empty arrays and it will use all available data from other vehicles as well as the Kalman filter predictions to create a best answer for where all objects are until hopefully the next iteration when the deadline is met again. TTPython also allows for a deadline to stop the subsequent SQ from firing as well using the TTContinue clause but setting it to false.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

import ticktalkpython.DebugLogger as log
import logging

test_name = "example_4_two_cavs_fusion_stream_deadline_ensemble"
simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg --timeout 10000000000
# Out:
# /content/ticktalkpython
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# Started YOLO successfully...
# Started LIDAR successfully...
# Started FUSION successfully...
# Opening captured video file  /content/yolofiles/cav1/live_test_output.avi
# Started YOLO successfully...
# Started LIDAR successfully...
# Started FUSION successfully...
# Started FUSION successfully...
# Processed global fusion @  1689372818.3330343
# Processed global fusion @  1689372819.7359033
# Processed global fusion @  1689372821.8496523
# Processed global fusion @  1689372822.8718066
# Processed global fusion @  1689372823.8896327
# Processed global fusion @  1689372824.824949
# Processed global fusion @  1689372826.2686334
# Processed global fusion @  1689372827.8883252
# Processed global fusion @  1689372829.2859907
# Processed global fusion @  1689372830.711823
# Processed global fusion @  1689372846.7499664
# Processed global fusion @  1689372869.51912
# Processed global fusion @  1689372891.056727
# Processed global fusion @  1689372913.4709995
# Cleaning track  27
# Cleaning track  27
# Processed global fusion @  1689372932.7118628
# Cleaning track  27
# Processed global fusion @  1689372952.2976387
# Cleaning track  27
# Processed global fusion @  1689372974.5081925
# Cleaning track  27
# Cleaning track  28
# Processed global fusion @  1689372997.7382247
# Cleaning track  28
# Processed global fusion @  1689373020.9374456
# Cleaning track  28
# Processed global fusion @  1689373043.8103614
# Cleaning track  28
# Processed global fusion @  1689373066.6928616
# Cleaning track  28
# Processed global fusion @  1689373089.7466025
# Cleaning track  28
# Processed global fusion @  1689373112.581182
# Cleaning track  28
# Processed global fusion @  1689373134.1409125
# Cleaning track  28
# Processed global fusion @  1689373156.2775593
# Cleaning track  28
# Processed global fusion @  1689373178.138563
# Cleaning track  28
# Processed global fusion @  1689373198.8644335
# Cleaning track  28
# Processed global fusion @  1689373221.0605953
# Cleaning track  28
# Processed global fusion @  1689373242.7420971
# Cleaning track  28
# Processed global fusion @  1689373272.4212022

# %% [markdown]
# **Step 12: Test the Plan Be Deadline Construct**
# Let us purposefully introduce some errors into the streams of example 4 so that we can test out the deadline construct. In order to do this we will be using a TTPython testing construct that allows us to note send a token. We will then selectively not send a token from CAV1 every 4th time the local sensor fusion is called on CAV1. This would simulate a connection link going down or being too slow resulting in the need to fire the global fusion without the data. Due to some slowdowns we have simulating all aspects of this demo on Google Colab this plan B deadline fires every 10 seconds but in the real CAVs it would be set to 100 milliseconds after the streamify nodes fire. What we should see if the log level is set to Warn is that the global fusion node will fire and we will get an output in the example_4_output.txt file for each iteration despite the fact CAV1 will not send any results every 4th iteration. Our global fusion will receive an empty array from PlanB for CAV1 and the Kalman filter will run without input for many of the tracked objects. However the Kalman filter is set up to keep tracking objects until it does not see them for at least 4 iterations so what will happen is that we will get a predicted output from the global fusion for these select tracks for the specific iteration that the CAV1 does not send any output. However the next data frame CAV1 will send data as usual and as long as the prediction was not too far off the matching step will still be able to associate it with the correct data from CAV1 and the Kalman Filter will continue almost as if nothing had happened. This is a very important feature for real time cyber-physical systems with slow communication or other problems where missing data is not uncommon so we must operate on what data we have.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

test_name = "example_4_two_cavs_fusion_stream_deadline_ensemble_test"
compile_arg = f"examples/tutorial/{test_name}.py"
# %run compile.py $compile_arg

# %cd /content/ticktalkpython/

import ticktalkpython.DebugLogger as log
import logging

log.set_base_logger_level(logging.WARN)

# Remove our old output file
# !rm /content/ticktalkpython/output/example_4_output.txt

simulate_arg = f"./output/{test_name}.pickle"
# %run simulate.py $simulate_arg --timeout 10000000000
# Out:
# /content/ticktalkpython
# Compiling example_4_two_cavs_fusion_stream_deadline_ensemble_test
# TTPython.Compiler:INFO:: Compilation successful
# TTPython.Compiler:INFO:: Writing ./output/example_4_two_cavs_fusion_stream_deadline_ensemble_test.pickle
# Compiled output found at ./output/example_4_two_cavs_fusion_stream_deadline_ensemble_test.pickle
# /content/ticktalkpython
# rm: cannot remove '/content/ticktalkpython/output/example_4_output.txt': No such file or directory
# TTPython.example_4_two_cavs_fusion_stream_deadline_ensemble_test:INFO:: setup sim
# TTPython.example_4_two_cavs_fusion_stream_deadline_ensemble_test:INFO:: setup ensembles
# TTPython.Ensemble:INFO:: Creating a new TTEnsemble: runtime-manager
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.example_4_two_cavs_fusion_stream_deadline_ensemble_test:INFO:: send graph inputs
# TTPython.Ensemble(runtime-manager):INFO:: Begin steady state
# TTPython.InputTokenProcess-runtime-manager:INFO:: run sim loop InputTokens
# TTPython.ExecutionProcess-runtime-manager:INFO:: run sim loop Execute
# TTPython.NetworkManager(runtime-manager):INFO:: run sim loop NetworkManager
# TTPython.RuntimeManager(runtime-manager):INFO:: run sim loop RuntimeManager
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x78ac82307ac0 - type=RuntimeMsg.JoinTickTalkSystem; recipient=Recipient.ProcessRuntimeManager; payload={'name': 'runtime-manager', 'address': <ticktalkpython.Ensemble.TTEnsemble object at 0x78ac823140d0>}>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.JoinTickTalkSystem
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82307ca0 - type=NetMsg.AddRoutingTableEntry; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', <ticktalkpython.Ensemble.TTEnsemble object at 0x78ac823140d0>)>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.RuntimeManager(runtime-manager):INFO:: Sending PropagateRoutingTable message via <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x78ac82306050>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac8228b400 - type=NetMsg.PropagateRoutingTable; recipient=Recipient.ProcessNetwork; payload=runtime-manager>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.RuntimeManager(runtime-manager):INFO:: Completed JoinTickTalkSystem
# TTPython.Ensemble(runtime-manager):INFO:: Entering ensemble steady state (simulated)
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.PropagateRoutingTable
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.AddRoutingTableEntry
# TTPython.example_4_two_cavs_fusion_stream_deadline_ensemble_test:INFO:: Distribute Graph to ensembles
# TTPython.RuntimeManager:INFO:: input_msg()
# TTPython.RuntimeManager(runtime-manager):INFO:: *** Message: <Message 0x78ac82495960 - type=RuntimeMsg.InstantiateAndMapGraph; recipient=Recipient.ProcessRuntimeManager; payload=<ticktalkpython.Graph.TTGraph object at 0x78ac822881f0>>
# TTPython.RuntimeManager(runtime-manager):INFO:: New message of type RuntimeMsg.InstantiateAndMapGraph
# TTPython.RuntimeManager(runtime-manager):INFO:: Send clocks to Ensemble(runtime-manager)
# TTPython.RuntimeManager(runtime-manager):INFO:: Input function is <bound method TTNetworkManager.input_msg of <ticktalkpython.NetworkManager.TTNetworkManager object at 0x78ac82306050>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac824942e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82496320 - type=SyncMsg.AddClocks; recipient=Recipient.ProcessInputTokens; payload=[<TTClock ROOT ROOT>]>, <Message 0x78ac824942b0 - type=ExecuteMsg.AddClocks; recipient=Recipient.ProcessExecute; payload=[<TTClock ROOT ROOT>]>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82496260 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac824943a0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82495b40>>, <Message 0x78ac82494250 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824958a0>>, <Message 0x78ac824941f0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-0', [[<TTArcDestination Ens=runtime-manager; SQ-name=COPY_TTTIME-7; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac824940d0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82494220 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824810f0>>, <Message 0x78ac82494490 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82480f70>>, <Message 0x78ac82494130 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('READ_TTCLOCK-1', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-5; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=VALUES_TO_TTTIME-6; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac824976a0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82495630 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82481a20>>, <Message 0x78ac82494070 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82481840>>, <Message 0x78ac82496920 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-2', [[<TTArcDestination Ens=runtime-manager; SQ-name=MULT-4; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac824972e0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82495360 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82481e70>>, <Message 0x78ac82497610 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82481b10>>, <Message 0x78ac82497310 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-3', [[<TTArcDestination Ens=runtime-manager; SQ-name=MULT-4; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497430 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497340 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82481b40>>, <Message 0x78ac82497550 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82481540>>, <Message 0x78ac82497400 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('MULT-4', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-5; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497100 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497520 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82481510>>, <Message 0x78ac82497580 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82481120>>, <Message 0x78ac824971f0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('ADD-5', [[<TTArcDestination Ens=runtime-manager; SQ-name=VALUES_TO_TTTIME-6; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82496fe0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497250 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824822c0>>, <Message 0x78ac82497130 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82481ff0>>, <Message 0x78ac82497010 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('VALUES_TO_TTTIME-6', [[<TTArcDestination Ens=runtime-manager; SQ-name=COPY_TTTIME-7; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82496e30 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497040 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82495e10>>, <Message 0x78ac82496f50 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82495b10>>, <Message 0x78ac82496e00 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('COPY_TTTIME-7', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-9; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-10; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-18; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-19; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82496c50 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82496f20 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824835b0>>, <Message 0x78ac82496d10 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824835e0>>, <Message 0x78ac82496d40 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-8', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-9; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-10; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=2>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82496aa0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82496ce0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82496440>>, <Message 0x78ac82496b60 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82495f00>>, <Message 0x78ac82496bf0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('camera_sampler-9', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_camera-11; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=READ_TTCLOCK-14; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497820 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82496ad0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82480a60>>, <Message 0x78ac82496a70 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824832e0>>, <Message 0x78ac82496980 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('lidar_sampler-10', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_lidar-12; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497940 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82496a10 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82496830>>, <Message 0x78ac82497fa0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824964d0>>, <Message 0x78ac824977c0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_camera-11', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497e80 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497fd0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82480d30>>, <Message 0x78ac82497eb0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82480ac0>>, <Message 0x78ac82497e20 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_lidar-12', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-13; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497d00 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497c70 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b04c0>>, <Message 0x78ac82497af0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82496860>>, <Message 0x78ac82497d90 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('local_fusion-13', [[<TTArcDestination Ens=runtime-manager; SQ-name=DEADLINE-23; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82497d30 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497bb0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82482c20>>, <Message 0x78ac82497e50 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82482ef0>>, <Message 0x78ac82497cd0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('READ_TTCLOCK-14', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-16; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82317700 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac823179d0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f4190>>, <Message 0x78ac82316740 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f4310>>, <Message 0x78ac823146a0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-15', [[<TTArcDestination Ens=runtime-manager; SQ-name=ADD-16; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82314790 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82316c50 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82482e30>>, <Message 0x78ac823176d0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f7ca0>>, <Message 0x78ac82317b20 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('ADD-16', [[<TTArcDestination Ens=runtime-manager; SQ-name=DEADLINE-23; Port=1>, <TTArcDestination Ens=runtime-manager; SQ-name=DEADLINE-26; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82316e60 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82497dc0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f41c0>>, <Message 0x78ac82307fd0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f47f0>>, <Message 0x78ac82316d10 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('CONST-17', [[<TTArcDestination Ens=runtime-manager; SQ-name=camera_sampler-18; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=lidar_sampler-19; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-22; Port=2>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82317a90 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317ac0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f4d90>>, <Message 0x78ac823173a0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f5960>>, <Message 0x78ac82314ca0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('camera_sampler-18', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_camera-20; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82317280 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317f70 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f7610>>, <Message 0x78ac82314d60 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f57e0>>, <Message 0x78ac82317d60 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('lidar_sampler-19', [[<TTArcDestination Ens=runtime-manager; SQ-name=process_lidar-21; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82316920 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317310 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f4f70>>, <Message 0x78ac823172e0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b10f0>>, <Message 0x78ac82316440 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_camera-20', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-22; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82317d90 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82316410 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac822f5240>>, <Message 0x78ac82317430 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac822f5720>>, <Message 0x78ac82317d30 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('process_lidar-21', [[<TTArcDestination Ens=runtime-manager; SQ-name=local_fusion-22; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82317610 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317970 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b1060>>, <Message 0x78ac82317400 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b1630>>, <Message 0x78ac82314cd0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('local_fusion-22', [[<TTArcDestination Ens=runtime-manager; SQ-name=DEADLINE-26; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82315de0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82315a20 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b01c0>>, <Message 0x78ac82317190 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b0490>>, <Message 0x78ac823174f0 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('DEADLINE-23', [[<TTArcDestination Ens=runtime-manager; SQ-name=MERGE-25; Port=0>], [<TTArcDestination Ens=runtime-manager; SQ-name=deadline_check-24; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=deadline_check-24; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82315a80 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317250 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82483c40>>, <Message 0x78ac82317520 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac82483bb0>>, <Message 0x78ac82317040 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('deadline_check-24', [[<TTArcDestination Ens=runtime-manager; SQ-name=MERGE-25; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82315c00 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac823174c0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b3e50>>, <Message 0x78ac82315390 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b0220>>, <Message 0x78ac82316e30 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('MERGE-25', [[<TTArcDestination Ens=runtime-manager; SQ-name=global_fusion-29; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac823162f0 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82317070 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b1b10>>, <Message 0x78ac82316e00 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b20b0>>, <Message 0x78ac82314340 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('DEADLINE-26', [[<TTArcDestination Ens=runtime-manager; SQ-name=MERGE-28; Port=0>], [<TTArcDestination Ens=runtime-manager; SQ-name=deadline_check-27; Port=0>, <TTArcDestination Ens=runtime-manager; SQ-name=deadline_check-27; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82316020 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac823171f0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b0100>>, <Message 0x78ac82315ba0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b3ca0>>, <Message 0x78ac82316620 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('deadline_check-27', [[<TTArcDestination Ens=runtime-manager; SQ-name=MERGE-28; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82316b30 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac823156f0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b2050>>, <Message 0x78ac823158d0 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b0640>>, <Message 0x78ac82315420 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('MERGE-28', [[<TTArcDestination Ens=runtime-manager; SQ-name=global_fusion-29; Port=1>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82316f80 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac823144c0 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac824b2440>>, <Message 0x78ac82316140 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824b2830>>, <Message 0x78ac82314d00 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('global_fusion-29', [[<TTArcDestination Ens=runtime-manager; SQ-name=write_to_file-30; Port=0>]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <Message 0x78ac82314310 - type=NetMsg.ForwardNetworkMessage; recipient=Recipient.ProcessNetwork; payload=('runtime-manager', [<Message 0x78ac82315570 - type=SyncMsg.InstantiateSQ; recipient=Recipient.ProcessInputTokens; payload=<ticktalkpython.SQSync.TTSQSync object at 0x78ac82483940>>, <Message 0x78ac82316d70 - type=ExecuteMsg.InstantiateSQ; recipient=Recipient.ProcessExecute; payload=<ticktalkpython.SQExecute.TTSQExecute object at 0x78ac824828f0>>, <Message 0x78ac82315150 - type=NetMsg.InstantiateSQ; recipient=Recipient.ProcessNetwork; payload=('write_to_file-30', [[]])>])>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.ForwardNetworkMessage
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.InstantiateSQ
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.AddClocks
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-0 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ READ_TTCLOCK-1 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-2 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-3 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ MULT-4 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ ADD-5 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ VALUES_TO_TTTIME-6 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ COPY_TTTIME-7 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-8 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ camera_sampler-9 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ lidar_sampler-10 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_camera-11 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_lidar-12 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ local_fusion-13 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ READ_TTCLOCK-14 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-15 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ ADD-16 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ CONST-17 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ camera_sampler-18 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ lidar_sampler-19 with firing rule TTFiringRuleType.TimedRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_camera-20 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ process_lidar-21 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ local_fusion-22 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ DEADLINE-23 with firing rule TTFiringRuleType.Deadline
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ deadline_check-24 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ MERGE-25 with firing rule TTFiringRuleType.Immediate
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ DEADLINE-26 with firing rule TTFiringRuleType.Deadline
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ deadline_check-27 with firing rule TTFiringRuleType.Timed
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ MERGE-28 with firing rule TTFiringRuleType.Immediate
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ global_fusion-29 with firing rule TTFiringRuleType.SequentialRetrigger
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InstantiateSQ
# TTPython.SQSync:INFO:: Instantiate runtime SQ synchronization for SQ write_to_file-30 with firing rule TTFiringRuleType.Timed
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.AddClocks
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-0
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ READ_TTCLOCK-1
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-2
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-3
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ MULT-4
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ ADD-5
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ VALUES_TO_TTTIME-6
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ COPY_TTTIME-7
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-8
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ camera_sampler-9
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ lidar_sampler-10
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_camera-11
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_lidar-12
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ local_fusion-13
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ READ_TTCLOCK-14
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-15
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ ADD-16
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ CONST-17
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ camera_sampler-18
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ lidar_sampler-19
# TTPython.SQExecute:INFO:: replacing clock during SQExecute runtime instantiation
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# TTPython.ExecutionProcess-runtime-manager:INFO:: Instantiate SQ process_camera-20
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.InstantiateSQ
# ...
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ process_lidar-12; Removing everything with time intervals older than 14375000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ process_lidar-12
# TTPython.ExecutionProcess-runtime-manager:INFO:: Retriggering: <TTToken None T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,9223372036854775807)>, Tag:<TTTag: u=u1.sq=process_lidar-12.p=1.e=runtime-manager>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[0.0, 0.0, 0.0613464, 17, 1517160746.5664134], [[-4.161485424970492, 2.169182054605492], [-2.4520121473433587, 1.7074304555412414], [-2.396276243540492, 2.2495823156077397], [-2.262571737426346, 2.6178096542059257], [-0.7941839987150091, 2.9281044317512057], [0.5612206162492384, 0.8744999106000035], [4.5543772148196515, 2.186128516683054], [0.9464793964718238, -0.010848635003059095], [4.83832487751983, -0.7098341403224252], [4.173274908487379, -1.2118422403252824], [2.691389482521364, -1.576450915515018], [2.215591598317573, -3.2150140190353853], [1.3629719556048858, -3.461497190594554], [0.627025355102258, -6.416860083825762], [-0.7660457798847969, -1.3944595829814352], [-5.032994306586203, -1.879427822976608], [2.3520867746795684, -2.8223279080008767], [4.873083468931643, 1.0482250254621799], [3.9831240507702876, 2.792228654848519]], 1517160746.583402, 1694554850.4970508, 1694554850.5955625] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'process_lidar-12', 'execute_time': 45000000, 'completion_time': 45000000}>]; source='process_lidar-12'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ local_fusion-13; Removing everything with time intervals older than 14375000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ local_fusion-13
# TTPython.ExecutionProcess-runtime-manager:INFO:: Retriggering: <TTToken None T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,9223372036854775807)>, Tag:<TTTag: u=u1.sq=local_fusion-13.p=3.e=runtime-manager>>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[], 1517160746.566424, [-0.75, 0.0, 0.0613464, 17, 1517160746.5664134], [1694554849.3436754, 1694554850.4970508, 1694554850.431016, 1694554850.5955625, 1694554851.052913]] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'local_fusion-13', 'execute_time': 45000000, 'completion_time': 45000000}>]; source='local_fusion-13'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Deadline trigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ DEADLINE-23; Removing everything with time intervals older than 14375000
# TTPython.SQSync:INFO:: We removed 1 tokens with garbage collection!
# TTPython.SQSync:INFO:: New Execution context for SQ DEADLINE-23
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ DEADLINE-23
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[], 1517160746.566424, [-0.75, 0.0, 0.0613464, 17, 1517160746.5664134], [1694554849.3436754, 1694554850.4970508, 1694554850.431016, 1694554850.5955625, 1694554851.052913]] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'DEADLINE-23', 'execute_time': 45000000, 'completion_time': 45000000}>, <NetMsgToken msg_type:<NetMsg.EmptyToken: 2>; payload={'token': <TTToken <ticktalkpython.Empty.TTEmpty object at 0x78ac3d4be6e0> T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'DEADLINE-23', 'execute_time': 45000000, 'completion_time': 45000000}>]; source='DEADLINE-23'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Immediate untimed firing rule call
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ MERGE-25
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [[], 1517160746.566424, [-0.75, 0.0, 0.0613464, 17, 1517160746.5664134], [1694554849.3436754, 1694554850.4970508, 1694554850.431016, 1694554850.5955625, 1694554851.052913]] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'MERGE-25', 'execute_time': 45000000, 'completion_time': 45000000}>]; source='MERGE-25'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Timed retrigger firing rule call
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.TimedInput
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ camera_sampler-18
# TTPython.NetworkManager(runtime-manager):INFO:: *** Received input message <SendTokenListMessage - type=<NetMsg.SendTokenList: 0>; recipient=<Recipient.ProcessNetwork: 3>; payload=[<NetMsgToken msg_type:<NetMsg.SendToken: 1>; payload={'token': <TTToken [array([[[146, 116, 175],
#         [149, 119, 178],
#         [151, 121, 180],
#         ...,
#         [252, 252, 255],
#         [252, 251, 255],
#         [253, 252, 255]],
#
#        [[150, 120, 179],
#         [152, 122, 181],
#         [153, 123, 182],
#         ...,
#         [253, 253, 255],
#         [253, 252, 255],
#         [253, 252, 255]],
#
#        [[148, 116, 182],
#         [150, 118, 184],
#         [151, 119, 185],
#         ...,
#         [250, 249, 255],
#         [251, 255, 255],
#         [249, 253, 253]],
#
#        ...,
#
#        [[168, 141, 200],
#         [165, 138, 197],
#         [163, 136, 197],
#         ...,
#         [184, 155, 228],
#         [184, 157, 224],
#         [181, 154, 221]],
#
#        [[163, 136, 197],
#         [161, 134, 195],
#         [159, 131, 194],
#         ...,
#         [184, 155, 228],
#         [185, 159, 224],
#         [182, 156, 221]],
#
#        [[158, 131, 192],
#         [157, 130, 191],
#         [156, 128, 191],
#         ...,
#         [184, 155, 228],
#         [186, 160, 225],
#         [183, 157, 222]]], dtype=uint8), 1517160746.566424, 1694554851.143101] T:<TTTimeSpec c:<TTClockSpec name:ROOT, parent:None>, (44375000,45625000)>, Tag:<TTTag: u=u1.sq=None.p=None.e=None>>, 'source_sq': 'camera_sampler-18', 'execute_time': 45000000, 'completion_time': 45000000}>]; source='camera_sampler-18'>
# TTPython.NetworkManager(runtime-manager):INFO:: *** Going into queue <queue.Queue object at 0x78ac82316890>
# TTPython.NetworkManager(runtime-manager):INFO:: New message of type NetMsg.SendTokenList
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Sequential retrigger firing rule call
# TTPython.SQSync:INFO:: Time-based garbage collection for SQ process_camera-20; Removing everything with time intervals older than 14375000
# TTPython.ExecutionProcess-runtime-manager:INFO:: New message of type ExecuteMsg.NewExecutionContext
# TTPython.ExecutionProcess-runtime-manager:INFO:: Execute for SQ process_camera-20
# TTPython.executeProcess:INFO:: Caught BaseException
# Traceback (most recent call last):
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 336, in run_sim
#     self.handle_message(next_msg)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 438, in handle_message
#     self.execute(execution_context)
#   File "/content/ticktalkpython/ticktalkpython/ExecuteProcess.py", line 802, in execute
#     return_token_list = sq_execute.function(
#   File "/content/ticktalkpython/ticktalkpython/SQ.py", line 771, in wrapper
#     return_value = function(*token_values, **kwargs)
#   File "", line 24, in process_camera
#   File "/content/ticktalkpython/libraries/camera_recognition.py", line 603, in processCameraFrame
#     coordinates, timestamp = self.yolo.readFrame(frame_read, cam_time_data)
#   File "/content/ticktalkpython/libraries/camera_recognition.py", line 453, in readFrame
#     detections = darknet.detect_image((self.network), (self.class_names), (self.darknet_image), thresh=0.25)
#   File "/content/darknet/darknet.py", line 246, in detect_image
#     predict_image(network, image)
# KeyboardInterrupt
# TTPython.InputTokenProcess-runtime-manager:INFO:: New message of type SyncMsg.InputToken
# TTPython.SQSync:INFO:: Timed retrigger firing rule call
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in run_sim(self, sim)
#     198                     try:
# --> 199                         self.handle_message(next_msg)
#     200                     except BaseException:
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in handle_message(self, msg)
#     290             self.logger.debug(f'Input token: {token}')
# --> 291             self.find_sq_and_sync(token)
#     292             #if synchronization completed, then a message will be send in the
#
# /content/ticktalkpython/ticktalkpython/InputTokenProcess.py in find_sq_and_sync(self, token)
#     416                 Recipient.ProcessExecute)
# --> 417             self.input_execute_func(execution_message)
#     418
#
# /content/ticktalkpython/ticktalkpython/ExecuteProcess.py in input_msg(self, message)
#     283                 and self.sim.active_process != self.sim_process):
# --> 284             self.sim_process.interrupt()
#     285
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in interrupt(self, cause)
#     377         """
# --> 378         Interruption(self, cause)
#     379
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in __init__(self, process, cause)
#     285         if process._value is not PENDING:
# --> 286             raise RuntimeError(
#     287                 f'{process} has terminated and cannot be interrupted.'
#
# RuntimeError: <Process(run_sim) object at 0x78ac823074c0> has terminated and cannot be interrupted.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /content/ticktalkpython/simulate.py in <module>
#     108
#     109 if __name__ == "__main__":
# --> 110     main()
#
# /content/ticktalkpython/simulate.py in main()
#     104     rtm.manager_ensemble.enter_steady_state(timeout=timeout)
#     105
# --> 106     sim.run(until=timeout)
#     107
#     108
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     252         try:
#     253             while True:
# --> 254                 self.step()
#     255         except StopSimulation as exc:
#     256             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     204             exc = type(event._value)(*event._value.args)
#     205             exc.__cause__ = event._value
# --> 206             raise exc
#     207
#     208     def run(
#
# RuntimeError: <Process(run_sim) object at 0x78ac823074c0> has terminated and cannot be interrupted.

# %% [markdown]
# **End of Beginner Section:**
# If you have made it to this point then it is safe to consider yourself a beginer user of TTPython, congradulations! The following steps in the tutorial get progressivly harder and involve conversion of vanilla Python coder over to TTPython should you choose to accept the challenge but with it comes with the ability to graduate to intermediate or even expert TTPython user.

# %% [markdown]
# **Step 12: (Intermediate) Convert Example 1 from Non-TTPython to TTPython:**
# Here is the code for example 1 but not using the TTPython constructs. It is worth mentioning this will not work exactly the same as the TTPython version as many of the timing guarantees are not present here - nor is the example automatically threaded like TTPython is. Your task here, should you choose to accept it will help you solidify all the TTPython concepts you learned today. Try running this example code. After that, open up the source code and try to convert it to TTPython. If you can complete this task for this simple application you can move onto the next example which is more complex.

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

# non tt-python version
# !cd examples/ && python streamify_camera_darknet_non_tt.py

# %% [markdown]
# **Step 13: (Advanced) Converting Example 2 Non-TTPython to TTPython:**
# Similar to step 12, we are once again giving you the code for a regular python version of example 2. It has more streamify nodes and starts to introduce the concepts of merging streams and data interval validity. If you can convert this example over and get it to run similarly to the python version it is safe to say you are now an Advanced TTPython user!

# %%
# Check our directory just in case
# %cd /content/ticktalkpython/

# non tt-python version
# !python examples/streamify_camera_lidar_non_tt.py

# %% [markdown]
# **Step 14: (Expert) The Grande Finale - Use Example 2 Python Code to Create Examples 3 and 4:** TTPython is very versatile. In the previous steps 11 and 12 we gave you non-TTPython code to convert over. To get to Example 3 and 4 doesn't require any additional code. What it does require is properly creating duplicate versions of that code to create a second CAV as well as the RSU which is calling the same local sensor fusion algorithm again to get the global fusion. To get to the examples 3 you must properly declare ensembles and multiple copies of the code that you created in example 2. And finally to get to example 4 you need to surround the global fusion inputs with the PlanB deadline construct and set the timing of that correctly. If you can accomplish all of this you can officially call yourself a TTPython Expert user!
